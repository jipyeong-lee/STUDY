# %% [markdown]
# # 데모

# %% [markdown]
# ## 라이브러리 import 및 설정

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import lightgbm as lgb
from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
import seaborn as sns
import warnings

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
pd.set_option('max_columns', 100)
pd.set_option("display.precision", 4)
warnings.simplefilter('ignore')

# %% [markdown]
# ## 학습데이터 로드

# %% [markdown]
# [03-pandas-eda.ipynb](https://github.com/kaggler-tv/dku-kaggle-class/blob/master/notebook/03-pandas-eda.ipynb)에서 생성한 `feature.csv` 피처파일 사용

# %%
data_dir = Path('..dataset/input/')
feature_dir = Path('..dataset/input/')
val_dir = Path('../build/val')
tst_dir = Path('../build/tst')
sub_dir = Path('../build/sub')

trn_file = data_dir / 'train.csv'
tst_file = data_dir / 'test.csv'
sample_file = data_dir / 'sample_submission.csv'

target_col = 'class'
n_fold = 5
n_class = 3
seed = 42

# %%
algo_name = 'lgbcv'
feature_name = 'feature'
model_name = f'{algo_name}_{feature_name}'

feature_file = feature_dir / f'{feature_name}.csv'
p_val_file = val_dir / f'{model_name}.val.csv'
p_tst_file = tst_dir / f'{model_name}.tst.csv'
sub_file = sub_dir / f'{model_name}.csv'

# %%
df = pd.read_csv('C:/Users/leeji/ML_/2020 캐글뽀개기/dataset/input/feature.csv', index_col=0)
print(df.shape)
df.head()
# Out:
# (400000, 20)
#           z    redshift  dered_u  dered_g  dered_r  dered_i  dered_z  \
# id
# 0   16.9396 -8.1086e-05  23.1243  20.2578  18.9551  17.6321  16.9089
# 1   13.1689  4.5061e-03  14.9664  14.0045  13.4114  13.2363  13.1347
# 2   15.3500  4.7198e-04  16.6076  15.6866  15.4400  15.3217  15.2961
# 3   19.6346  5.8143e-06  25.3536  20.9947  20.0873  19.7947  19.5552
# 4   17.9826 -3.3247e-05  23.7714  20.4338  18.8630  18.1903  17.8759
#
#     nObserve  airmass_u  class  d_dered_u  d_dered_g  d_dered_r  d_dered_i  \
# id
# 0     2.9444     1.1898    0.0    -0.1397    -0.0790    -0.0544    -0.0403
# 1     0.6931     1.2533    1.0    -0.0857    -0.0574    -0.0410    -0.0322
# 2     1.0986     1.0225    0.0    -0.1787    -0.1388    -0.0963    -0.0718
# 3     1.6094     1.2054    0.0    -0.3070    -0.1941    -0.1339    -0.1003
# 4     2.6391     1.1939    0.0    -0.6820    -0.2653    -0.1794    -0.1339
#
#     d_dered_z  d_dered_ig  d_dered_zg  d_dered_rz  d_dered_iz  d_obs_det
# id
# 0     -0.0307     -2.6257     -3.3488      2.0462      0.7232   -15.0556
# 1     -0.0343     -0.7683     -0.8698      0.2767      0.1016    -0.3069
# 2     -0.0540     -0.3649     -0.3905      0.1440      0.0257    -0.9014
# 3     -0.0795     -1.2000     -1.4395      0.5321      0.2395    -1.3906
# 4     -0.1067     -2.2436     -2.5579      0.9871      0.3144    -9.3609

# %%
y = df[target_col].values[:320000]
df.drop(target_col, axis=1, inplace=True)
trn = df.iloc[:320000].values
tst = df.iloc[320000:].values
feature_name = df.columns.tolist()
print(y.shape, trn.shape, tst.shape)
# Out:
# (320000,) (320000, 19) (80000, 19)

# %% [markdown]
# ## Stratified K-Fold Cross Validation

# %%
cv = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)

# %% [markdown]
# ## LightGBM 모델 학습

# %%
p_val = np.zeros((trn.shape[0], n_class))
p_tst = np.zeros((tst.shape[0], n_class))
for i, (i_trn, i_val) in enumerate(cv.split(trn, y), 1):
    print(f'training model for CV #{i}')
    clf = lgb.LGBMClassifier(objective='multiclass',
                             n_estimators=1000,
                             num_leaves=64,
                             learning_rate=0.1,
                             min_child_samples=10,
                             subsample=.5,
                             subsample_freq=1,
                             colsample_bytree=.8,
                             random_state=seed,
                             n_jobs=-1)
    clf.fit(trn[i_trn], y[i_trn],
            eval_set=[(trn[i_val], y[i_val])],
            eval_metric='multiclass',
            early_stopping_rounds=10)
    
    p_val[i_val, :] = clf.predict_proba(trn[i_val])
    p_tst += clf.predict_proba(tst) / n_fold
# Out:
# training model for CV #1
# [1]	valid_0's multi_logloss: 0.860242
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761507
# [3]	valid_0's multi_logloss: 0.675529
# [4]	valid_0's multi_logloss: 0.604629
# [5]	valid_0's multi_logloss: 0.546718
# [6]	valid_0's multi_logloss: 0.505092
# [7]	valid_0's multi_logloss: 0.467961
# [8]	valid_0's multi_logloss: 0.440039
# [9]	valid_0's multi_logloss: 0.411566
# [10]	valid_0's multi_logloss: 0.382604
# [11]	valid_0's multi_logloss: 0.358461
# [12]	valid_0's multi_logloss: 0.337889
# [13]	valid_0's multi_logloss: 0.319551
# [14]	valid_0's multi_logloss: 0.303063
# [15]	valid_0's multi_logloss: 0.288774
# [16]	valid_0's multi_logloss: 0.276421
# [17]	valid_0's multi_logloss: 0.266034
# [18]	valid_0's multi_logloss: 0.25627
# [19]	valid_0's multi_logloss: 0.24705
# [20]	valid_0's multi_logloss: 0.240043
# [21]	valid_0's multi_logloss: 0.232841
# [22]	valid_0's multi_logloss: 0.226516
# [23]	valid_0's multi_logloss: 0.220679
# [24]	valid_0's multi_logloss: 0.21643
# [25]	valid_0's multi_logloss: 0.212494
# [26]	valid_0's multi_logloss: 0.208963
# [27]	valid_0's multi_logloss: 0.205259
# [28]	valid_0's multi_logloss: 0.201556
# [29]	valid_0's multi_logloss: 0.198271
# [30]	valid_0's multi_logloss: 0.195633
# [31]	valid_0's multi_logloss: 0.193161
# [32]	valid_0's multi_logloss: 0.191123
# [33]	valid_0's multi_logloss: 0.188817
# [34]	valid_0's multi_logloss: 0.186829
# [35]	valid_0's multi_logloss: 0.185004
# [36]	valid_0's multi_logloss: 0.183722
# [37]	valid_0's multi_logloss: 0.182204
# [38]	valid_0's multi_logloss: 0.180839
# [39]	valid_0's multi_logloss: 0.179766
# [40]	valid_0's multi_logloss: 0.178579
# [41]	valid_0's multi_logloss: 0.177435
# [42]	valid_0's multi_logloss: 0.17653
# [43]	valid_0's multi_logloss: 0.175633
# [44]	valid_0's multi_logloss: 0.174709
# [45]	valid_0's multi_logloss: 0.174157
# [46]	valid_0's multi_logloss: 0.173621
# [47]	valid_0's multi_logloss: 0.173069
# [48]	valid_0's multi_logloss: 0.172433
# [49]	valid_0's multi_logloss: 0.17176
# [50]	valid_0's multi_logloss: 0.171325
# [51]	valid_0's multi_logloss: 0.17087
# [52]	valid_0's multi_logloss: 0.170487
# [53]	valid_0's multi_logloss: 0.169999
# [54]	valid_0's multi_logloss: 0.169745
# [55]	valid_0's multi_logloss: 0.169523
# [56]	valid_0's multi_logloss: 0.169095
# [57]	valid_0's multi_logloss: 0.168732
# [58]	valid_0's multi_logloss: 0.168457
# [59]	valid_0's multi_logloss: 0.168168
# [60]	valid_0's multi_logloss: 0.167859
# [61]	valid_0's multi_logloss: 0.167575
# [62]	valid_0's multi_logloss: 0.167322
# [63]	valid_0's multi_logloss: 0.16716
# [64]	valid_0's multi_logloss: 0.166861
# [65]	valid_0's multi_logloss: 0.16664
# [66]	valid_0's multi_logloss: 0.16644
# [67]	valid_0's multi_logloss: 0.166183
# [68]	valid_0's multi_logloss: 0.166071
# [69]	valid_0's multi_logloss: 0.165885
# [70]	valid_0's multi_logloss: 0.165759
# [71]	valid_0's multi_logloss: 0.165702
# [72]	valid_0's multi_logloss: 0.165788
# [73]	valid_0's multi_logloss: 0.165987
# [74]	valid_0's multi_logloss: 0.168272
# [75]	valid_0's multi_logloss: 0.167624
# [76]	valid_0's multi_logloss: 0.167442
# [77]	valid_0's multi_logloss: 0.166103
# [78]	valid_0's multi_logloss: 0.165983
# [79]	valid_0's multi_logloss: 0.165917
# [80]	valid_0's multi_logloss: 0.165804
# [81]	valid_0's multi_logloss: 0.165709
# Early stopping, best iteration is:
# [71]	valid_0's multi_logloss: 0.165702
# training model for CV #2
# [1]	valid_0's multi_logloss: 0.860915
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.76197
# [3]	valid_0's multi_logloss: 0.676398
# [4]	valid_0's multi_logloss: 0.605823
# [5]	valid_0's multi_logloss: 0.548198
# [6]	valid_0's multi_logloss: 0.506777
# [7]	valid_0's multi_logloss: 0.469543
# [8]	valid_0's multi_logloss: 0.441524
# [9]	valid_0's multi_logloss: 0.413574
# [10]	valid_0's multi_logloss: 0.38471
# [11]	valid_0's multi_logloss: 0.360615
# [12]	valid_0's multi_logloss: 0.340045
# [13]	valid_0's multi_logloss: 0.321831
# [14]	valid_0's multi_logloss: 0.305077
# [15]	valid_0's multi_logloss: 0.290812
# [16]	valid_0's multi_logloss: 0.278506
# [17]	valid_0's multi_logloss: 0.267993
# [18]	valid_0's multi_logloss: 0.258331
# [19]	valid_0's multi_logloss: 0.249247
# [20]	valid_0's multi_logloss: 0.242136
# [21]	valid_0's multi_logloss: 0.234789
# [22]	valid_0's multi_logloss: 0.228279
# [23]	valid_0's multi_logloss: 0.222443
# [24]	valid_0's multi_logloss: 0.218273
# [25]	valid_0's multi_logloss: 0.214134
# [26]	valid_0's multi_logloss: 0.210449
# [27]	valid_0's multi_logloss: 0.206408
# [28]	valid_0's multi_logloss: 0.202829
# [29]	valid_0's multi_logloss: 0.199493
# [30]	valid_0's multi_logloss: 0.19697
# [31]	valid_0's multi_logloss: 0.194403
# [32]	valid_0's multi_logloss: 0.192297
# [33]	valid_0's multi_logloss: 0.190002
# [34]	valid_0's multi_logloss: 0.188078
# [35]	valid_0's multi_logloss: 0.186272
# [36]	valid_0's multi_logloss: 0.184911
# [37]	valid_0's multi_logloss: 0.183404
# [38]	valid_0's multi_logloss: 0.181957
# [39]	valid_0's multi_logloss: 0.180943
# [40]	valid_0's multi_logloss: 0.179686
# [41]	valid_0's multi_logloss: 0.178528
# [42]	valid_0's multi_logloss: 0.177653
# [43]	valid_0's multi_logloss: 0.176708
# [44]	valid_0's multi_logloss: 0.175816
# [45]	valid_0's multi_logloss: 0.175197
# [46]	valid_0's multi_logloss: 0.174579
# [47]	valid_0's multi_logloss: 0.173892
# [48]	valid_0's multi_logloss: 0.173347
# [49]	valid_0's multi_logloss: 0.172801
# [50]	valid_0's multi_logloss: 0.172337
# [51]	valid_0's multi_logloss: 0.17176
# [52]	valid_0's multi_logloss: 0.171293
# [53]	valid_0's multi_logloss: 0.170801
# [54]	valid_0's multi_logloss: 0.170548
# [55]	valid_0's multi_logloss: 0.170293
# [56]	valid_0's multi_logloss: 0.169954
# [57]	valid_0's multi_logloss: 0.169625
# [58]	valid_0's multi_logloss: 0.16922
# [59]	valid_0's multi_logloss: 0.169035
# [60]	valid_0's multi_logloss: 0.168794
# [61]	valid_0's multi_logloss: 0.168502
# [62]	valid_0's multi_logloss: 0.168198
# [63]	valid_0's multi_logloss: 0.167906
# [64]	valid_0's multi_logloss: 0.167585
# [65]	valid_0's multi_logloss: 0.167461
# [66]	valid_0's multi_logloss: 0.167249
# [67]	valid_0's multi_logloss: 0.167384
# [68]	valid_0's multi_logloss: 0.167244
# [69]	valid_0's multi_logloss: 0.167065
# [70]	valid_0's multi_logloss: 0.166886
# [71]	valid_0's multi_logloss: 0.1668
# [72]	valid_0's multi_logloss: 0.166622
# [73]	valid_0's multi_logloss: 0.1665
# [74]	valid_0's multi_logloss: 0.166336
# [75]	valid_0's multi_logloss: 0.166249
# [76]	valid_0's multi_logloss: 0.166113
# [77]	valid_0's multi_logloss: 0.166022
# [78]	valid_0's multi_logloss: 0.165864
# [79]	valid_0's multi_logloss: 0.165749
# [80]	valid_0's multi_logloss: 0.165645
# [81]	valid_0's multi_logloss: 0.165589
# [82]	valid_0's multi_logloss: 0.165487
# [83]	valid_0's multi_logloss: 0.165429
# [84]	valid_0's multi_logloss: 0.165356
# [85]	valid_0's multi_logloss: 0.165279
# [86]	valid_0's multi_logloss: 0.165078
# [87]	valid_0's multi_logloss: 0.165034
# [88]	valid_0's multi_logloss: 0.164902
# [89]	valid_0's multi_logloss: 0.164865
# [90]	valid_0's multi_logloss: 0.164789
# [91]	valid_0's multi_logloss: 0.164789
# [92]	valid_0's multi_logloss: 0.164668
# [93]	valid_0's multi_logloss: 0.164493
# [94]	valid_0's multi_logloss: 0.164462
# [95]	valid_0's multi_logloss: 0.164371
# [96]	valid_0's multi_logloss: 0.164352
# [97]	valid_0's multi_logloss: 0.16427
# [98]	valid_0's multi_logloss: 0.164173
# [99]	valid_0's multi_logloss: 0.164154
# [100]	valid_0's multi_logloss: 0.164105
# [101]	valid_0's multi_logloss: 0.1641
# [102]	valid_0's multi_logloss: 0.164019
# [103]	valid_0's multi_logloss: 0.164015
# [104]	valid_0's multi_logloss: 0.163904
# [105]	valid_0's multi_logloss: 0.163889
# [106]	valid_0's multi_logloss: 0.163826
# [107]	valid_0's multi_logloss: 0.163793
# [108]	valid_0's multi_logloss: 0.163767
# [109]	valid_0's multi_logloss: 0.16379
# [110]	valid_0's multi_logloss: 0.163752
# [111]	valid_0's multi_logloss: 0.163716
# [112]	valid_0's multi_logloss: 0.163677
# [113]	valid_0's multi_logloss: 0.163646
# [114]	valid_0's multi_logloss: 0.163624
# [115]	valid_0's multi_logloss: 0.163599
# [116]	valid_0's multi_logloss: 0.163607
# [117]	valid_0's multi_logloss: 0.163575
# [118]	valid_0's multi_logloss: 0.163596
# [119]	valid_0's multi_logloss: 0.163553
# [120]	valid_0's multi_logloss: 0.163545
# [121]	valid_0's multi_logloss: 0.163542
# [122]	valid_0's multi_logloss: 0.163534
# [123]	valid_0's multi_logloss: 0.16351
# [124]	valid_0's multi_logloss: 0.163512
# [125]	valid_0's multi_logloss: 0.163507
# [126]	valid_0's multi_logloss: 0.163473
# [127]	valid_0's multi_logloss: 0.163482
# [128]	valid_0's multi_logloss: 0.163436
# [129]	valid_0's multi_logloss: 0.163437
# [130]	valid_0's multi_logloss: 0.163441
# [131]	valid_0's multi_logloss: 0.163416
# [132]	valid_0's multi_logloss: 0.163423
# [133]	valid_0's multi_logloss: 0.163405
# [134]	valid_0's multi_logloss: 0.163393
# [135]	valid_0's multi_logloss: 0.163356
# [136]	valid_0's multi_logloss: 0.163338
# [137]	valid_0's multi_logloss: 0.163326
# [138]	valid_0's multi_logloss: 0.163399
# [139]	valid_0's multi_logloss: 0.163428
# [140]	valid_0's multi_logloss: 0.163397
# [141]	valid_0's multi_logloss: 0.163383
# [142]	valid_0's multi_logloss: 0.163355
# [143]	valid_0's multi_logloss: 0.163365
# [144]	valid_0's multi_logloss: 0.163432
# [145]	valid_0's multi_logloss: 0.163416
# [146]	valid_0's multi_logloss: 0.163417
# [147]	valid_0's multi_logloss: 0.163447
# Early stopping, best iteration is:
# [137]	valid_0's multi_logloss: 0.163326
# training model for CV #3
# [1]	valid_0's multi_logloss: 0.860647
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761945
# [3]	valid_0's multi_logloss: 0.67616
# [4]	valid_0's multi_logloss: 0.605966
# [5]	valid_0's multi_logloss: 0.548445
# [6]	valid_0's multi_logloss: 0.506522
# [7]	valid_0's multi_logloss: 0.469404
# [8]	valid_0's multi_logloss: 0.441636
# [9]	valid_0's multi_logloss: 0.413747
# [10]	valid_0's multi_logloss: 0.384979
# [11]	valid_0's multi_logloss: 0.361187
# [12]	valid_0's multi_logloss: 0.340562
# [13]	valid_0's multi_logloss: 0.322392
# [14]	valid_0's multi_logloss: 0.305659
# [15]	valid_0's multi_logloss: 0.29145
# [16]	valid_0's multi_logloss: 0.279118
# [17]	valid_0's multi_logloss: 0.26873
# [18]	valid_0's multi_logloss: 0.259066
# [19]	valid_0's multi_logloss: 0.249754
# [20]	valid_0's multi_logloss: 0.242714
# [21]	valid_0's multi_logloss: 0.235387
# [22]	valid_0's multi_logloss: 0.229085
# [23]	valid_0's multi_logloss: 0.223277
# [24]	valid_0's multi_logloss: 0.219255
# [25]	valid_0's multi_logloss: 0.214988
# [26]	valid_0's multi_logloss: 0.211372
# [27]	valid_0's multi_logloss: 0.207482
# [28]	valid_0's multi_logloss: 0.203863
# [29]	valid_0's multi_logloss: 0.20076
# [30]	valid_0's multi_logloss: 0.198185
# [31]	valid_0's multi_logloss: 0.195527
# [32]	valid_0's multi_logloss: 0.19352
# [33]	valid_0's multi_logloss: 0.191399
# [34]	valid_0's multi_logloss: 0.189279
# [35]	valid_0's multi_logloss: 0.18739
# [36]	valid_0's multi_logloss: 0.185895
# [37]	valid_0's multi_logloss: 0.184464
# [38]	valid_0's multi_logloss: 0.182999
# [39]	valid_0's multi_logloss: 0.181779
# [40]	valid_0's multi_logloss: 0.180515
# [41]	valid_0's multi_logloss: 0.179333
# [42]	valid_0's multi_logloss: 0.178356
# [43]	valid_0's multi_logloss: 0.177444
# [44]	valid_0's multi_logloss: 0.176641
# [45]	valid_0's multi_logloss: 0.176044
# [46]	valid_0's multi_logloss: 0.17544
# [47]	valid_0's multi_logloss: 0.174763
# [48]	valid_0's multi_logloss: 0.174173
# [49]	valid_0's multi_logloss: 0.173588
# [50]	valid_0's multi_logloss: 0.173036
# [51]	valid_0's multi_logloss: 0.172492
# [52]	valid_0's multi_logloss: 0.172149
# [53]	valid_0's multi_logloss: 0.171679
# [54]	valid_0's multi_logloss: 0.171418
# [55]	valid_0's multi_logloss: 0.171152
# [56]	valid_0's multi_logloss: 0.170824
# [57]	valid_0's multi_logloss: 0.170482
# [58]	valid_0's multi_logloss: 0.170188
# [59]	valid_0's multi_logloss: 0.169938
# [60]	valid_0's multi_logloss: 0.16973
# [61]	valid_0's multi_logloss: 0.169498
# [62]	valid_0's multi_logloss: 0.169237
# [63]	valid_0's multi_logloss: 0.168928
# [64]	valid_0's multi_logloss: 0.168704
# [65]	valid_0's multi_logloss: 0.1685
# [66]	valid_0's multi_logloss: 0.168251
# [67]	valid_0's multi_logloss: 0.168035
# [68]	valid_0's multi_logloss: 0.167867
# [69]	valid_0's multi_logloss: 0.167851
# [70]	valid_0's multi_logloss: 0.167728
# [71]	valid_0's multi_logloss: 0.167637
# [72]	valid_0's multi_logloss: 0.167499
# [73]	valid_0's multi_logloss: 0.167362
# [74]	valid_0's multi_logloss: 0.167284
# [75]	valid_0's multi_logloss: 0.167175
# [76]	valid_0's multi_logloss: 0.16695
# [77]	valid_0's multi_logloss: 0.166802
# [78]	valid_0's multi_logloss: 0.166753
# [79]	valid_0's multi_logloss: 0.166602
# [80]	valid_0's multi_logloss: 0.166544
# [81]	valid_0's multi_logloss: 0.166485
# [82]	valid_0's multi_logloss: 0.166428
# [83]	valid_0's multi_logloss: 0.166265
# [84]	valid_0's multi_logloss: 0.166188
# [85]	valid_0's multi_logloss: 0.166078
# [86]	valid_0's multi_logloss: 0.166023
# [87]	valid_0's multi_logloss: 0.165934
# [88]	valid_0's multi_logloss: 0.165857
# [89]	valid_0's multi_logloss: 0.165757
# [90]	valid_0's multi_logloss: 0.165712
# [91]	valid_0's multi_logloss: 0.165678
# [92]	valid_0's multi_logloss: 0.165588
# [93]	valid_0's multi_logloss: 0.165489
# [94]	valid_0's multi_logloss: 0.165414
# [95]	valid_0's multi_logloss: 0.165381
# [96]	valid_0's multi_logloss: 0.16533
# [97]	valid_0's multi_logloss: 0.16524
# [98]	valid_0's multi_logloss: 0.16521
# [99]	valid_0's multi_logloss: 0.1651
# [100]	valid_0's multi_logloss: 0.165088
# [101]	valid_0's multi_logloss: 0.165062
# [102]	valid_0's multi_logloss: 0.165008
# [103]	valid_0's multi_logloss: 0.165017
# [104]	valid_0's multi_logloss: 0.164971
# [105]	valid_0's multi_logloss: 0.164922
# [106]	valid_0's multi_logloss: 0.164898
# [107]	valid_0's multi_logloss: 0.164833
# [108]	valid_0's multi_logloss: 0.164799
# [109]	valid_0's multi_logloss: 0.164769
# [110]	valid_0's multi_logloss: 0.16474
# [111]	valid_0's multi_logloss: 0.16476
# [112]	valid_0's multi_logloss: 0.164698
# [113]	valid_0's multi_logloss: 0.164649
# [114]	valid_0's multi_logloss: 0.164667
# [115]	valid_0's multi_logloss: 0.164684
# [116]	valid_0's multi_logloss: 0.164683
# [117]	valid_0's multi_logloss: 0.164669
# [118]	valid_0's multi_logloss: 0.164708
# [119]	valid_0's multi_logloss: 0.164711
# [120]	valid_0's multi_logloss: 0.164712
# [121]	valid_0's multi_logloss: 0.164701
# [122]	valid_0's multi_logloss: 0.164702
# [123]	valid_0's multi_logloss: 0.164658
# Early stopping, best iteration is:
# [113]	valid_0's multi_logloss: 0.164649
# training model for CV #4
# [1]	valid_0's multi_logloss: 0.860231
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761194
# [3]	valid_0's multi_logloss: 0.675562
# [4]	valid_0's multi_logloss: 0.605081
# [5]	valid_0's multi_logloss: 0.547323
# [6]	valid_0's multi_logloss: 0.505819
# [7]	valid_0's multi_logloss: 0.468913
# [8]	valid_0's multi_logloss: 0.441265
# [9]	valid_0's multi_logloss: 0.413212
# [10]	valid_0's multi_logloss: 0.384684
# [11]	valid_0's multi_logloss: 0.36052
# [12]	valid_0's multi_logloss: 0.339856
# [13]	valid_0's multi_logloss: 0.321732
# [14]	valid_0's multi_logloss: 0.305152
# [15]	valid_0's multi_logloss: 0.290668
# [16]	valid_0's multi_logloss: 0.278339
# [17]	valid_0's multi_logloss: 0.267942
# [18]	valid_0's multi_logloss: 0.25849
# [19]	valid_0's multi_logloss: 0.249181
# [20]	valid_0's multi_logloss: 0.242363
# [21]	valid_0's multi_logloss: 0.234813
# [22]	valid_0's multi_logloss: 0.228313
# [23]	valid_0's multi_logloss: 0.222409
# [24]	valid_0's multi_logloss: 0.218183
# [25]	valid_0's multi_logloss: 0.214347
# [26]	valid_0's multi_logloss: 0.210867
# [27]	valid_0's multi_logloss: 0.207084
# [28]	valid_0's multi_logloss: 0.203519
# [29]	valid_0's multi_logloss: 0.200099
# [30]	valid_0's multi_logloss: 0.197596
# [31]	valid_0's multi_logloss: 0.194921
# [32]	valid_0's multi_logloss: 0.192929
# [33]	valid_0's multi_logloss: 0.190809
# [34]	valid_0's multi_logloss: 0.188623
# [35]	valid_0's multi_logloss: 0.186762
# [36]	valid_0's multi_logloss: 0.185463
# [37]	valid_0's multi_logloss: 0.183905
# [38]	valid_0's multi_logloss: 0.182573
# [39]	valid_0's multi_logloss: 0.181502
# [40]	valid_0's multi_logloss: 0.180383
# [41]	valid_0's multi_logloss: 0.179252
# [42]	valid_0's multi_logloss: 0.178419
# [43]	valid_0's multi_logloss: 0.177628
# [44]	valid_0's multi_logloss: 0.176934
# [45]	valid_0's multi_logloss: 0.176284
# [46]	valid_0's multi_logloss: 0.175687
# [47]	valid_0's multi_logloss: 0.175077
# [48]	valid_0's multi_logloss: 0.174459
# [49]	valid_0's multi_logloss: 0.173949
# [50]	valid_0's multi_logloss: 0.173373
# [51]	valid_0's multi_logloss: 0.172855
# [52]	valid_0's multi_logloss: 0.172433
# [53]	valid_0's multi_logloss: 0.171953
# [54]	valid_0's multi_logloss: 0.171668
# [55]	valid_0's multi_logloss: 0.171399
# [56]	valid_0's multi_logloss: 0.171113
# [57]	valid_0's multi_logloss: 0.170778
# [58]	valid_0's multi_logloss: 0.170351
# [59]	valid_0's multi_logloss: 0.170088
# [60]	valid_0's multi_logloss: 0.169786
# [61]	valid_0's multi_logloss: 0.169443
# [62]	valid_0's multi_logloss: 0.169161
# [63]	valid_0's multi_logloss: 0.168955
# [64]	valid_0's multi_logloss: 0.168688
# [65]	valid_0's multi_logloss: 0.168527
# [66]	valid_0's multi_logloss: 0.168247
# [67]	valid_0's multi_logloss: 0.168083
# [68]	valid_0's multi_logloss: 0.167932
# [69]	valid_0's multi_logloss: 0.167781
# [70]	valid_0's multi_logloss: 0.167661
# [71]	valid_0's multi_logloss: 0.167501
# [72]	valid_0's multi_logloss: 0.167429
# [73]	valid_0's multi_logloss: 0.167289
# [74]	valid_0's multi_logloss: 0.167162
# [75]	valid_0's multi_logloss: 0.167074
# [76]	valid_0's multi_logloss: 0.166987
# [77]	valid_0's multi_logloss: 0.167141
# [78]	valid_0's multi_logloss: 0.167577
# [79]	valid_0's multi_logloss: 0.167076
# [80]	valid_0's multi_logloss: 0.167048
# [81]	valid_0's multi_logloss: 0.166954
# [82]	valid_0's multi_logloss: 0.166808
# [83]	valid_0's multi_logloss: 0.166674
# [84]	valid_0's multi_logloss: 0.166588
# [85]	valid_0's multi_logloss: 0.166402
# [86]	valid_0's multi_logloss: 0.166286
# [87]	valid_0's multi_logloss: 0.166209
# [88]	valid_0's multi_logloss: 0.166164
# [89]	valid_0's multi_logloss: 0.166047
# [90]	valid_0's multi_logloss: 0.165987
# [91]	valid_0's multi_logloss: 0.16591
# [92]	valid_0's multi_logloss: 0.165814
# [93]	valid_0's multi_logloss: 0.165721
# [94]	valid_0's multi_logloss: 0.165668
# [95]	valid_0's multi_logloss: 0.165616
# [96]	valid_0's multi_logloss: 0.165635
# [97]	valid_0's multi_logloss: 0.165586
# [98]	valid_0's multi_logloss: 0.165506
# [99]	valid_0's multi_logloss: 0.165399
# [100]	valid_0's multi_logloss: 0.165316
# [101]	valid_0's multi_logloss: 0.165272
# [102]	valid_0's multi_logloss: 0.165202
# [103]	valid_0's multi_logloss: 0.165151
# [104]	valid_0's multi_logloss: 0.165106
# [105]	valid_0's multi_logloss: 0.16507
# [106]	valid_0's multi_logloss: 0.165007
# [107]	valid_0's multi_logloss: 0.164989
# [108]	valid_0's multi_logloss: 0.164942
# [109]	valid_0's multi_logloss: 0.16489
# [110]	valid_0's multi_logloss: 0.164849
# [111]	valid_0's multi_logloss: 0.164878
# [112]	valid_0's multi_logloss: 0.164862
# [113]	valid_0's multi_logloss: 0.164873
# [114]	valid_0's multi_logloss: 0.164864
# [115]	valid_0's multi_logloss: 0.164839
# [116]	valid_0's multi_logloss: 0.164822
# [117]	valid_0's multi_logloss: 0.164756
# [118]	valid_0's multi_logloss: 0.164757
# [119]	valid_0's multi_logloss: 0.164702
# [120]	valid_0's multi_logloss: 0.164717
# [121]	valid_0's multi_logloss: 0.164713
# [122]	valid_0's multi_logloss: 0.164735
# [123]	valid_0's multi_logloss: 0.164693
# [124]	valid_0's multi_logloss: 0.164697
# [125]	valid_0's multi_logloss: 0.164647
# [126]	valid_0's multi_logloss: 0.164623
# [127]	valid_0's multi_logloss: 0.164616
# [128]	valid_0's multi_logloss: 0.164623
# [129]	valid_0's multi_logloss: 0.164563
# [130]	valid_0's multi_logloss: 0.164601
# [131]	valid_0's multi_logloss: 0.164589
# [132]	valid_0's multi_logloss: 0.164612
# [133]	valid_0's multi_logloss: 0.164583
# [134]	valid_0's multi_logloss: 0.164536
# [135]	valid_0's multi_logloss: 0.164559
# [136]	valid_0's multi_logloss: 0.164487
# [137]	valid_0's multi_logloss: 0.164475
# [138]	valid_0's multi_logloss: 0.164456
# [139]	valid_0's multi_logloss: 0.164437
# [140]	valid_0's multi_logloss: 0.164431
# [141]	valid_0's multi_logloss: 0.164428
# [142]	valid_0's multi_logloss: 0.164428
# [143]	valid_0's multi_logloss: 0.164453
# [144]	valid_0's multi_logloss: 0.164446
# [145]	valid_0's multi_logloss: 0.164391
# [146]	valid_0's multi_logloss: 0.164375
# [147]	valid_0's multi_logloss: 0.164398
# [148]	valid_0's multi_logloss: 0.164396
# [149]	valid_0's multi_logloss: 0.164339
# [150]	valid_0's multi_logloss: 0.164354
# [151]	valid_0's multi_logloss: 0.164333
# [152]	valid_0's multi_logloss: 0.164323
# [153]	valid_0's multi_logloss: 0.164336
# [154]	valid_0's multi_logloss: 0.164327
# [155]	valid_0's multi_logloss: 0.164282
# [156]	valid_0's multi_logloss: 0.16429
# [157]	valid_0's multi_logloss: 0.164292
# [158]	valid_0's multi_logloss: 0.164316
# [159]	valid_0's multi_logloss: 0.164326
# [160]	valid_0's multi_logloss: 0.16429
# [161]	valid_0's multi_logloss: 0.164275
# [162]	valid_0's multi_logloss: 0.164284
# [163]	valid_0's multi_logloss: 0.164268
# [164]	valid_0's multi_logloss: 0.164278
# [165]	valid_0's multi_logloss: 0.16424
# [166]	valid_0's multi_logloss: 0.164267
# [167]	valid_0's multi_logloss: 0.164222
# [168]	valid_0's multi_logloss: 0.164206
# [169]	valid_0's multi_logloss: 0.164203
# [170]	valid_0's multi_logloss: 0.16419
# [171]	valid_0's multi_logloss: 0.16415
# [172]	valid_0's multi_logloss: 0.16414
# [173]	valid_0's multi_logloss: 0.164121
# [174]	valid_0's multi_logloss: 0.164137
# [175]	valid_0's multi_logloss: 0.164142
# [176]	valid_0's multi_logloss: 0.164131
# [177]	valid_0's multi_logloss: 0.164174
# [178]	valid_0's multi_logloss: 0.164165
# [179]	valid_0's multi_logloss: 0.164135
# [180]	valid_0's multi_logloss: 0.164124
# [181]	valid_0's multi_logloss: 0.16419
# [182]	valid_0's multi_logloss: 0.164178
# [183]	valid_0's multi_logloss: 0.164182
# Early stopping, best iteration is:
# [173]	valid_0's multi_logloss: 0.164121
# training model for CV #5
# [1]	valid_0's multi_logloss: 0.860564
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761594
# [3]	valid_0's multi_logloss: 0.67603
# [4]	valid_0's multi_logloss: 0.605837
# [5]	valid_0's multi_logloss: 0.548037
# [6]	valid_0's multi_logloss: 0.506358
# [7]	valid_0's multi_logloss: 0.469213
# [8]	valid_0's multi_logloss: 0.441455
# [9]	valid_0's multi_logloss: 0.413156
# [10]	valid_0's multi_logloss: 0.384379
# [11]	valid_0's multi_logloss: 0.360088
# [12]	valid_0's multi_logloss: 0.339502
# [13]	valid_0's multi_logloss: 0.321287
# [14]	valid_0's multi_logloss: 0.304545
# [15]	valid_0's multi_logloss: 0.290144
# [16]	valid_0's multi_logloss: 0.278102
# [17]	valid_0's multi_logloss: 0.267614
# [18]	valid_0's multi_logloss: 0.257737
# [19]	valid_0's multi_logloss: 0.248362
# [20]	valid_0's multi_logloss: 0.241603
# [21]	valid_0's multi_logloss: 0.234247
# [22]	valid_0's multi_logloss: 0.227692
# [23]	valid_0's multi_logloss: 0.221839
# [24]	valid_0's multi_logloss: 0.217484
# [25]	valid_0's multi_logloss: 0.21321
# [26]	valid_0's multi_logloss: 0.209606
# [27]	valid_0's multi_logloss: 0.20577
# [28]	valid_0's multi_logloss: 0.202061
# [29]	valid_0's multi_logloss: 0.19882
# [30]	valid_0's multi_logloss: 0.19619
# [31]	valid_0's multi_logloss: 0.193525
# [32]	valid_0's multi_logloss: 0.191448
# [33]	valid_0's multi_logloss: 0.189134
# [34]	valid_0's multi_logloss: 0.187059
# [35]	valid_0's multi_logloss: 0.185187
# [36]	valid_0's multi_logloss: 0.183784
# [37]	valid_0's multi_logloss: 0.182325
# [38]	valid_0's multi_logloss: 0.180969
# [39]	valid_0's multi_logloss: 0.180031
# [40]	valid_0's multi_logloss: 0.178821
# [41]	valid_0's multi_logloss: 0.177849
# [42]	valid_0's multi_logloss: 0.17697
# [43]	valid_0's multi_logloss: 0.176111
# [44]	valid_0's multi_logloss: 0.175241
# [45]	valid_0's multi_logloss: 0.174708
# [46]	valid_0's multi_logloss: 0.174102
# [47]	valid_0's multi_logloss: 0.173474
# [48]	valid_0's multi_logloss: 0.172871
# [49]	valid_0's multi_logloss: 0.172193
# [50]	valid_0's multi_logloss: 0.171719
# [51]	valid_0's multi_logloss: 0.17108
# [52]	valid_0's multi_logloss: 0.170686
# [53]	valid_0's multi_logloss: 0.170177
# [54]	valid_0's multi_logloss: 0.169833
# [55]	valid_0's multi_logloss: 0.169949
# [56]	valid_0's multi_logloss: 0.169497
# [57]	valid_0's multi_logloss: 0.169262
# [58]	valid_0's multi_logloss: 0.168939
# [59]	valid_0's multi_logloss: 0.16856
# [60]	valid_0's multi_logloss: 0.168257
# [61]	valid_0's multi_logloss: 0.167911
# [62]	valid_0's multi_logloss: 0.167703
# [63]	valid_0's multi_logloss: 0.167401
# [64]	valid_0's multi_logloss: 0.167215
# [65]	valid_0's multi_logloss: 0.166996
# [66]	valid_0's multi_logloss: 0.166787
# [67]	valid_0's multi_logloss: 0.166574
# [68]	valid_0's multi_logloss: 0.166358
# [69]	valid_0's multi_logloss: 0.166153
# [70]	valid_0's multi_logloss: 0.166006
# [71]	valid_0's multi_logloss: 0.165866
# [72]	valid_0's multi_logloss: 0.16574
# [73]	valid_0's multi_logloss: 0.165629
# [74]	valid_0's multi_logloss: 0.165509
# [75]	valid_0's multi_logloss: 0.165412
# [76]	valid_0's multi_logloss: 0.165346
# [77]	valid_0's multi_logloss: 0.165231
# [78]	valid_0's multi_logloss: 0.165073
# [79]	valid_0's multi_logloss: 0.164953
# [80]	valid_0's multi_logloss: 0.164921
# [81]	valid_0's multi_logloss: 0.164746
# [82]	valid_0's multi_logloss: 0.164646
# [83]	valid_0's multi_logloss: 0.164595
# [84]	valid_0's multi_logloss: 0.164465
# [85]	valid_0's multi_logloss: 0.164385
# [86]	valid_0's multi_logloss: 0.164274
# [87]	valid_0's multi_logloss: 0.165246
# [88]	valid_0's multi_logloss: 0.165102
# [89]	valid_0's multi_logloss: 0.165117
# [90]	valid_0's multi_logloss: 0.167365
# [91]	valid_0's multi_logloss: 0.167443
# [92]	valid_0's multi_logloss: 0.167326
# [93]	valid_0's multi_logloss: 0.166697
# [94]	valid_0's multi_logloss: 0.16669
# [95]	valid_0's multi_logloss: 0.168145
# [96]	valid_0's multi_logloss: 0.166572
# Early stopping, best iteration is:
# [86]	valid_0's multi_logloss: 0.164274

# %%
print(f'{accuracy_score(y, np.argmax(p_val, axis=1)) * 100:.4f}%')
# Out:
# 93.1072%

# %%
print(p_val.shape, p_tst.shape)
# Out:
# (320000, 3) (80000, 3)

# %%
np.savetxt(p_val_file, p_val, fmt='%.6f', delimiter=',')
np.savetxt(p_tst_file, p_tst, fmt='%.6f', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-67358c712669> in <module>
# ----> 1 np.savetxt(p_val_file, p_val, fmt='%.6f', delimiter=',')
#       2 np.savetxt(p_tst_file, p_tst, fmt='%.6f', delimiter=',')
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1355     if _is_string_like(fname):
#    1356         # datasource doesn't support creating a new file ...
# -> 1357         open(fname, 'wt').close()
#    1358         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1359         own_fh = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\build\\val\\lgbcv_feature.val.csv'

# %% [markdown]
# ## 피처 중요도 시각화

# %%
imp = pd.DataFrame({'feature': df.columns, 'importance': clf.feature_importances_})
imp = imp.sort_values('importance').set_index('feature')
imp.plot(kind='barh')

# %% [markdown]
# ## 제출 파일 생성

# %%
sub = pd.read_csv(sample_file, index_col=0)
print(sub.shape)
sub.head()

# %%
sub[target_col] = np.argmax(p_tst, axis=1)
sub.head()

# %%
sub[target_col].value_counts()

# %%
sub.to_csv(sub_file)
