# %% [markdown]
# ### Bayesian Optimization을 이용하여 application과 previous로 만들어진 집합의 하이퍼 파라미터 튜닝

# %% [markdown]
# #### 라이브러리 및 데이터 세트 로딩. 이전 application 데이터의 FE 함수 복사

# %%
import numpy as np
import pandas as pd
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)

# %%
def get_dataset():
    app_train = pd.read_csv('application_train.csv')
    app_test = pd.read_csv('application_test.csv')
    apps = pd.concat([app_train, app_test])
    prev = pd.read_csv('previous_application.csv')

    return apps, prev

apps, prev = get_dataset()

# %% [markdown]
# #### 이전 application 데이터의 feature engineering 함수 복사

# %%
def get_apps_processed(apps):
    
    # EXT_SOURCE_X FEATURE 가공
    apps['APPS_EXT_SOURCE_MEAN'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps['APPS_EXT_SOURCE_STD'].fillna(apps['APPS_EXT_SOURCE_STD'].mean())
    
    # AMT_CREDIT 비율로 Feature 가공
    apps['APPS_ANNUITY_CREDIT_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_CREDIT']
    apps['APPS_GOODS_CREDIT_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_CREDIT']
    
    # AMT_INCOME_TOTAL 비율로 Feature 가공
    apps['APPS_ANNUITY_INCOME_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CREDIT_INCOME_RATIO'] = apps['AMT_CREDIT']/apps['AMT_INCOME_TOTAL']
    apps['APPS_GOODS_INCOME_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CNT_FAM_INCOME_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['CNT_FAM_MEMBERS']
    
    # DAYS_BIRTH, DAYS_EMPLOYED 비율로 Feature 가공
    apps['APPS_EMPLOYED_BIRTH_RATIO'] = apps['DAYS_EMPLOYED']/apps['DAYS_BIRTH']
    apps['APPS_INCOME_EMPLOYED_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_EMPLOYED']
    apps['APPS_INCOME_BIRTH_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_BIRTH']
    apps['APPS_CAR_BIRTH_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_EMPLOYED_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_EMPLOYED']
    
    return apps

# %% [markdown]
# #### previous 데이터 가공후 인코딩 및 최종 데이터 집합 생성하는 함수 선언

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

def get_prev_processed(prev):
    # 대출 신청 금액과 실제 대출액/대출 상품금액 차이 및 비율
    prev['PREV_CREDIT_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_CREDIT']
    prev['PREV_GOODS_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_GOODS_PRICE']
    prev['PREV_CREDIT_APPL_RATIO'] = prev['AMT_CREDIT']/prev['AMT_APPLICATION']
    # prev['PREV_ANNUITY_APPL_RATIO'] = prev['AMT_ANNUITY']/prev['AMT_APPLICATION']
    prev['PREV_GOODS_APPL_RATIO'] = prev['AMT_GOODS_PRICE']/prev['AMT_APPLICATION']
    
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # 첫번째 만기일과 마지막 만기일까지의 기간
    prev['PREV_DAYS_LAST_DUE_DIFF'] = prev['DAYS_LAST_DUE_1ST_VERSION'] - prev['DAYS_LAST_DUE']
    # 매월 납부 금액과 납부 횟수 곱해서 전체 납부 금액 구함. 
    all_pay = prev['AMT_ANNUITY'] * prev['CNT_PAYMENT']
    # 전체 납부 금액 대비 AMT_CREDIT 비율을 구하고 여기에 다시 납부횟수로 나누어서 이자율 계산. 
    prev['PREV_INTERESTS_RATE'] = (all_pay/prev['AMT_CREDIT'] - 1)/prev['CNT_PAYMENT']
        
    return prev
    
    
def get_prev_amt_agg(prev):
    # 새롭게 생성된 대출 신청액 대비 다른 금액 차이 및 비율로 aggregation 수행. 
    agg_dict = {
         # 기존 컬럼. 
        'SK_ID_CURR':['count'],
        'AMT_CREDIT':['mean', 'max', 'sum'],
        'AMT_ANNUITY':['mean', 'max', 'sum'], 
        'AMT_APPLICATION':['mean', 'max', 'sum'],
        'AMT_DOWN_PAYMENT':['mean', 'max', 'sum'],
        'AMT_GOODS_PRICE':['mean', 'max', 'sum'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
        # 가공 컬럼
        'PREV_CREDIT_DIFF':['mean', 'max', 'sum'], 
        'PREV_CREDIT_APPL_RATIO':['mean', 'max'],
        'PREV_GOODS_DIFF':['mean', 'max', 'sum'],
        'PREV_GOODS_APPL_RATIO':['mean', 'max'],
        'PREV_DAYS_LAST_DUE_DIFF':['mean', 'max', 'sum'],
        'PREV_INTERESTS_RATE':['mean', 'max']
    }

    prev_group = prev.groupby('SK_ID_CURR')
    prev_amt_agg = prev_group.agg(agg_dict)

    # multi index 컬럼을 '_'로 연결하여 컬럼명 변경
    prev_amt_agg.columns = ["PREV_"+ "_".join(x).upper() for x in prev_amt_agg.columns.ravel()]
    
    return prev_amt_agg

def get_prev_refused_appr_agg(prev):
    # 원래 groupby 컬럼 + 세부 기준 컬럼으로 groupby 수행. 세분화된 레벨로 aggregation 수행 한 뒤에 unstack()으로 컬럼레벨로 변형. 
    prev_refused_appr_group = prev[prev['NAME_CONTRACT_STATUS'].isin(['Approved', 'Refused'])].groupby([ 'SK_ID_CURR', 'NAME_CONTRACT_STATUS'])
    prev_refused_appr_agg = prev_refused_appr_group['SK_ID_CURR'].count().unstack()
    # 컬럼명 변경. 
    prev_refused_appr_agg.columns = ['PREV_APPROVED_COUNT', 'PREV_REFUSED_COUNT' ]
    # NaN값은 모두 0으로 변경. 
    prev_refused_appr_agg = prev_refused_appr_agg.fillna(0)
    
    return prev_refused_appr_agg

    

def get_prev_agg(prev):
    prev = get_prev_processed(prev)
    prev_amt_agg = get_prev_amt_agg(prev)
    prev_refused_appr_agg = get_prev_refused_appr_agg(prev)
    
    # prev_amt_agg와 조인. 
    prev_agg = prev_amt_agg.merge(prev_refused_appr_agg, on='SK_ID_CURR', how='left')
    # SK_ID_CURR별 과거 대출건수 대비 APPROVED_COUNT 및 REFUSED_COUNT 비율 생성. 
    prev_agg['PREV_REFUSED_RATIO'] = prev_agg['PREV_REFUSED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
    prev_agg['PREV_APPROVED_RATIO'] = prev_agg['PREV_APPROVED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
    # 'PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT' 컬럼 drop 
    prev_agg = prev_agg.drop(['PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT'], axis=1)
    
    return prev_agg

def get_apps_all_with_prev_agg(apps, prev):
    apps_all =  get_apps_processed(apps)
    prev_agg = get_prev_agg(prev)
    print('prev_agg shape:', prev_agg.shape)
    print('apps_all before merge shape:', apps_all.shape)
    apps_all = apps_all.merge(prev_agg, on='SK_ID_CURR', how='left')
    print('apps_all after merge with prev_agg shape:', apps_all.shape)
    
    return apps_all

def get_apps_all_encoded(apps_all):
    object_columns = apps_all.dtypes[apps_all.dtypes == 'object'].index.tolist()
    for column in object_columns:
        apps_all[column] = pd.factorize(apps_all[column])[0]
    
    return apps_all

def get_apps_all_train_test(apps_all):
    apps_all_train = apps_all[~apps_all['TARGET'].isnull()]
    apps_all_test = apps_all[apps_all['TARGET'].isnull()]

    apps_all_test = apps_all_test.drop('TARGET', axis=1)
    
    return apps_all_train, apps_all_test
    
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=2000,
                learning_rate=0.01,
                num_leaves=32,
                colsample_bytree=0.8,
                subsample=0.8,
                max_depth=8,
                reg_alpha=0.04,
                reg_lambda=0.07,
                min_child_weight=40,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %% [markdown]
# ##### 최종 집합 생성 및 인코딩, 학습/테스트 데이터 분리, 학습/검증 피처와 타겟 데이터 분리

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
target_app = apps_all_train['TARGET']
train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
# Out:
# prev_agg shape: (338857, 41)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 176)

# %% [markdown]
# #### Bayesian Optimization

# %%
# bayesian optimization 패키지 설치
# !pip install bayesian-optimization

# %%
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier

# %% [markdown]
# ##### 함수의 입력값 search 범위(하이퍼 파라미터 별 입력 범위) 를 설정

# %%
bayesian_params = {
    'max_depth':(8, 16),
    'num_leaves':(24, 64),
    'min_child_samples':(10, 200),
    'min_child_weight':(1, 50),
    'subsample':(0.5, 1),
    'colsample_bytree':(0.5, 1),
    'max_bin':(10, 500),
    'reg_lambda':(0.001, 10),
    'reg_alpha':(0.01, 50)
}

# %% [markdown]
# ##### 최대 값을 구할 함수 선언.
# * iteration 시 마다 hyperparameter를 입력받아 classifier 학습하고 roc_auc_score값을 반환

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample, 
                colsample_bytree, max_bin, reg_lambda, reg_alpha):
    
    params = {
        "n_estimators":500, "learning_rate":0.02,
        'max_depth':int(round(max_depth)),
        'num_leaves':int(round(num_leaves)),
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample':max(min(subsample, 1), 0),
        'colsample_bytree':max(min(colsample_bytree, 1), 0),
        'reg_lambda': max(reg_lambda,0),
        'reg_alpha': max(reg_alpha, 0)
    }
    
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    valid_proba = lgb_model.predict_proba(valid_x)[:, 1]
    roc_auc = roc_auc_score(valid_y, valid_proba)
    
    return roc_auc

# %% [markdown]
# ##### BayesianOptimization 객체 생성 후 함수 반환값이 최대가 되는 입력값 search를 위한 iteration 수행

# %%
lgbBO = BayesianOptimization(f=lgb_roc_eval, pbounds=bayesian_params, random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.76939	training's binary_logloss: 0.246123	valid_1's auc: 0.754829	valid_1's binary_logloss: 0.24904
# [200]	training's auc: 0.786839	training's binary_logloss: 0.238603	valid_1's auc: 0.765765	valid_1's binary_logloss: 0.244338
# [300]	training's auc: 0.798445	training's binary_logloss: 0.234177	valid_1's auc: 0.770953	valid_1's binary_logloss: 0.242492
# [400]	training's auc: 0.807429	training's binary_logloss: 0.230826	valid_1's auc: 0.773399	valid_1's binary_logloss: 0.241608
# [500]	training's auc: 0.815361	training's binary_logloss: 0.227893	valid_1's auc: 0.775071	valid_1's binary_logloss: 0.241002
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.815361	training's binary_logloss: 0.227893	valid_1's auc: 0.775071	valid_1's binary_logloss: 0.241002
# |  1        |  0.7751   |  0.7744   |  360.4    |  12.82    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.762191	training's binary_logloss: 0.247523	valid_1's auc: 0.753506	valid_1's binary_logloss: 0.249172
# [200]	training's auc: 0.779968	training's binary_logloss: 0.240536	valid_1's auc: 0.765565	valid_1's binary_logloss: 0.244327
# [300]	training's auc: 0.790636	training's binary_logloss: 0.236584	valid_1's auc: 0.77082	valid_1's binary_logloss: 0.242413
# [400]	training's auc: 0.798757	training's binary_logloss: 0.233639	valid_1's auc: 0.773745	valid_1's binary_logloss: 0.241383
# [500]	training's auc: 0.805706	training's binary_logloss: 0.231163	valid_1's auc: 0.77549	valid_1's binary_logloss: 0.240773
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805706	training's binary_logloss: 0.231163	valid_1's auc: 0.77549	valid_1's binary_logloss: 0.240773
# |  2        |  0.7755   |  0.6917   |  397.9    |  12.23    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775514	training's binary_logloss: 0.243894	valid_1's auc: 0.75713	valid_1's binary_logloss: 0.247994
# [200]	training's auc: 0.796346	training's binary_logloss: 0.235216	valid_1's auc: 0.768187	valid_1's binary_logloss: 0.243366
# [300]	training's auc: 0.811365	training's binary_logloss: 0.229477	valid_1's auc: 0.772646	valid_1's binary_logloss: 0.241729
# [400]	training's auc: 0.824113	training's binary_logloss: 0.224712	valid_1's auc: 0.775521	valid_1's binary_logloss: 0.24071
# [500]	training's auc: 0.834733	training's binary_logloss: 0.22069	valid_1's auc: 0.776663	valid_1's binary_logloss: 0.240307
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.834733	training's binary_logloss: 0.22069	valid_1's auc: 0.776663	valid_1's binary_logloss: 0.240307
# |  3        |  0.7767   |  0.8891   |  436.3    |  15.83    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.765829	training's binary_logloss: 0.246878	valid_1's auc: 0.753667	valid_1's binary_logloss: 0.24928
# [200]	training's auc: 0.78311	training's binary_logloss: 0.239727	valid_1's auc: 0.765055	valid_1's binary_logloss: 0.244565
# [300]	training's auc: 0.793564	training's binary_logloss: 0.235796	valid_1's auc: 0.770029	valid_1's binary_logloss: 0.242779
# [400]	training's auc: 0.801348	training's binary_logloss: 0.23289	valid_1's auc: 0.772556	valid_1's binary_logloss: 0.241879
# [500]	training's auc: 0.808298	training's binary_logloss: 0.230351	valid_1's auc: 0.774306	valid_1's binary_logloss: 0.24125
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.808298	training's binary_logloss: 0.230351	valid_1's auc: 0.774306	valid_1's binary_logloss: 0.24125
# |  4        |  0.7743   |  0.9723   |  265.7    |  11.32    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.765712	training's binary_logloss: 0.247389	valid_1's auc: 0.7534	valid_1's binary_logloss: 0.249724
# [200]	training's auc: 0.781535	training's binary_logloss: 0.240396	valid_1's auc: 0.764241	valid_1's binary_logloss: 0.244932
# [300]	training's auc: 0.791317	training's binary_logloss: 0.236623	valid_1's auc: 0.769311	valid_1's binary_logloss: 0.243074
# [400]	training's auc: 0.798981	training's binary_logloss: 0.233813	valid_1's auc: 0.772099	valid_1's binary_logloss: 0.2421
# [500]	training's auc: 0.805261	training's binary_logloss: 0.231522	valid_1's auc: 0.773754	valid_1's binary_logloss: 0.241538
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805261	training's binary_logloss: 0.231522	valid_1's auc: 0.773754	valid_1's binary_logloss: 0.241538
# |  5        |  0.7738   |  0.806    |  312.3    |  15.55    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.772004	training's binary_logloss: 0.245497	valid_1's auc: 0.755461	valid_1's binary_logloss: 0.248934
# [200]	training's auc: 0.790028	training's binary_logloss: 0.237677	valid_1's auc: 0.766024	valid_1's binary_logloss: 0.244256
# [300]	training's auc: 0.801675	training's binary_logloss: 0.233095	valid_1's auc: 0.770873	valid_1's binary_logloss: 0.242482
# [400]	training's auc: 0.810909	training's binary_logloss: 0.229566	valid_1's auc: 0.773562	valid_1's binary_logloss: 0.241511
# [500]	training's auc: 0.8191	training's binary_logloss: 0.226478	valid_1's auc: 0.775137	valid_1's binary_logloss: 0.240958
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.8191	training's binary_logloss: 0.226478	valid_1's auc: 0.775137	valid_1's binary_logloss: 0.240958
# |  6        |  0.7751   |  0.8492   |  489.7    |  8.981    |  133.0    |  9.607    |  57.99    |  23.74    |  6.018    |  0.9803   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.77526	training's binary_logloss: 0.24455	valid_1's auc: 0.758568	valid_1's binary_logloss: 0.248113
# [200]	training's auc: 0.794351	training's binary_logloss: 0.236046	valid_1's auc: 0.768765	valid_1's binary_logloss: 0.243231
# [300]	training's auc: 0.808133	training's binary_logloss: 0.230708	valid_1's auc: 0.773072	valid_1's binary_logloss: 0.24158
# [400]	training's auc: 0.819963	training's binary_logloss: 0.226293	valid_1's auc: 0.775756	valid_1's binary_logloss: 0.240643
# [500]	training's auc: 0.829798	training's binary_logloss: 0.222604	valid_1's auc: 0.776993	valid_1's binary_logloss: 0.240188
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.829798	training's binary_logloss: 0.222604	valid_1's auc: 0.776993	valid_1's binary_logloss: 0.240188
# |  7        |  0.777    |  0.6269   |  437.7    |  11.25    |  156.5    |  22.14    |  48.87    |  2.432    |  7.948    |  0.8027   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.762896	training's binary_logloss: 0.248021	valid_1's auc: 0.754743	valid_1's binary_logloss: 0.249388
# [200]	training's auc: 0.778987	training's binary_logloss: 0.241048	valid_1's auc: 0.765646	valid_1's binary_logloss: 0.244381
# [300]	training's auc: 0.789498	training's binary_logloss: 0.237132	valid_1's auc: 0.771041	valid_1's binary_logloss: 0.242368
# [400]	training's auc: 0.797354	training's binary_logloss: 0.234286	valid_1's auc: 0.773819	valid_1's binary_logloss: 0.241353
# [500]	training's auc: 0.803996	training's binary_logloss: 0.231898	valid_1's auc: 0.775528	valid_1's binary_logloss: 0.24074
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.803996	training's binary_logloss: 0.231898	valid_1's auc: 0.775528	valid_1's binary_logloss: 0.24074
# |  8        |  0.7755   |  0.6076   |  440.9    |  12.62    |  172.3    |  7.485    |  25.5     |  3.027    |  8.938    |  0.6857   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775172	training's binary_logloss: 0.243689	valid_1's auc: 0.757163	valid_1's binary_logloss: 0.247775
# [200]	training's auc: 0.796544	training's binary_logloss: 0.23501	valid_1's auc: 0.768331	valid_1's binary_logloss: 0.243219
# [300]	training's auc: 0.810438	training's binary_logloss: 0.229587	valid_1's auc: 0.772183	valid_1's binary_logloss: 0.241778
# [400]	training's auc: 0.82222	training's binary_logloss: 0.225183	valid_1's auc: 0.774574	valid_1's binary_logloss: 0.240956
# [500]	training's auc: 0.83196	training's binary_logloss: 0.221556	valid_1's auc: 0.775911	valid_1's binary_logloss: 0.240502
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83196	training's binary_logloss: 0.221556	valid_1's auc: 0.775911	valid_1's binary_logloss: 0.240502
# |  9        |  0.7759   |  0.9977   |  436.6    |  9.0      |  147.4    |  45.39    |  52.61    |  3.912    |  1.362    |  0.5864   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779485	training's binary_logloss: 0.243044	valid_1's auc: 0.759269	valid_1's binary_logloss: 0.24765
# [200]	training's auc: 0.80063	training's binary_logloss: 0.233856	valid_1's auc: 0.769277	valid_1's binary_logloss: 0.242971
# [300]	training's auc: 0.816705	training's binary_logloss: 0.227729	valid_1's auc: 0.773368	valid_1's binary_logloss: 0.241448
# [400]	training's auc: 0.83048	training's binary_logloss: 0.222529	valid_1's auc: 0.776004	valid_1's binary_logloss: 0.24051
# [500]	training's auc: 0.842427	training's binary_logloss: 0.218097	valid_1's auc: 0.777035	valid_1's binary_logloss: 0.240127
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.842427	training's binary_logloss: 0.218097	valid_1's auc: 0.777035	valid_1's binary_logloss: 0.240127
# |  10       |  0.777    |  0.6701   |  440.2    |  12.74    |  140.4    |  9.368    |  57.78    |  3.512    |  3.111    |  0.9486   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776701	training's binary_logloss: 0.244017	valid_1's auc: 0.758121	valid_1's binary_logloss: 0.248114
# [200]	training's auc: 0.795949	training's binary_logloss: 0.235495	valid_1's auc: 0.768027	valid_1's binary_logloss: 0.243442
# [300]	training's auc: 0.810055	training's binary_logloss: 0.230043	valid_1's auc: 0.772543	valid_1's binary_logloss: 0.241793
# [400]	training's auc: 0.821821	training's binary_logloss: 0.225584	valid_1's auc: 0.775153	valid_1's binary_logloss: 0.240868
# [500]	training's auc: 0.832459	training's binary_logloss: 0.221613	valid_1's auc: 0.776515	valid_1's binary_logloss: 0.240369
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.832459	training's binary_logloss: 0.221613	valid_1's auc: 0.776515	valid_1's binary_logloss: 0.240369
# |  11       |  0.7765   |  0.6897   |  437.1    |  10.66    |  139.8    |  7.79     |  56.61    |  9.517    |  1.885    |  0.7773   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777961	training's binary_logloss: 0.244044	valid_1's auc: 0.759813	valid_1's binary_logloss: 0.247937
# [200]	training's auc: 0.797241	training's binary_logloss: 0.235171	valid_1's auc: 0.769356	valid_1's binary_logloss: 0.243064
# [300]	training's auc: 0.811703	training's binary_logloss: 0.229526	valid_1's auc: 0.773422	valid_1's binary_logloss: 0.241479
# [400]	training's auc: 0.823977	training's binary_logloss: 0.224914	valid_1's auc: 0.775727	valid_1's binary_logloss: 0.24064
# [500]	training's auc: 0.834513	training's binary_logloss: 0.22098	valid_1's auc: 0.777014	valid_1's binary_logloss: 0.240185
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.834513	training's binary_logloss: 0.22098	valid_1's auc: 0.777014	valid_1's binary_logloss: 0.240185
# |  12       |  0.777    |  0.5482   |  456.3    |  10.32    |  150.2    |  18.04    |  53.9     |  1.219    |  8.931    |  0.6953   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776239	training's binary_logloss: 0.244018	valid_1's auc: 0.758338	valid_1's binary_logloss: 0.247948
# [200]	training's auc: 0.795747	training's binary_logloss: 0.235467	valid_1's auc: 0.768809	valid_1's binary_logloss: 0.243196
# [300]	training's auc: 0.809956	training's binary_logloss: 0.229984	valid_1's auc: 0.773277	valid_1's binary_logloss: 0.241523
# [400]	training's auc: 0.822057	training's binary_logloss: 0.225449	valid_1's auc: 0.775809	valid_1's binary_logloss: 0.240614
# [500]	training's auc: 0.832816	training's binary_logloss: 0.221484	valid_1's auc: 0.777232	valid_1's binary_logloss: 0.240117
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.832816	training's binary_logloss: 0.221484	valid_1's auc: 0.777232	valid_1's binary_logloss: 0.240117
# |  13       |  0.7772   |  0.6982   |  451.8    |  12.04    |  147.6    |  25.3     |  52.54    |  5.75     |  3.546    |  0.8092   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.77399	training's binary_logloss: 0.244477	valid_1's auc: 0.757749	valid_1's binary_logloss: 0.247988
# [200]	training's auc: 0.793952	training's binary_logloss: 0.236043	valid_1's auc: 0.768321	valid_1's binary_logloss: 0.243336
# [300]	training's auc: 0.808359	training's binary_logloss: 0.230584	valid_1's auc: 0.772914	valid_1's binary_logloss: 0.241625
# [400]	training's auc: 0.820295	training's binary_logloss: 0.226158	valid_1's auc: 0.775635	valid_1's binary_logloss: 0.240673
# [500]	training's auc: 0.830232	training's binary_logloss: 0.222418	valid_1's auc: 0.77675	valid_1's binary_logloss: 0.240259
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.830232	training's binary_logloss: 0.222418	valid_1's auc: 0.77675	valid_1's binary_logloss: 0.240259
# |  14       |  0.7768   |  0.6833   |  452.8    |  13.75    |  105.3    |  37.54    |  47.92    |  1.048    |  7.682    |  0.5974   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.77355	training's binary_logloss: 0.244329	valid_1's auc: 0.756363	valid_1's binary_logloss: 0.248098
# [200]	training's auc: 0.793984	training's binary_logloss: 0.23594	valid_1's auc: 0.767724	valid_1's binary_logloss: 0.243464
# [300]	training's auc: 0.807383	training's binary_logloss: 0.230746	valid_1's auc: 0.772097	valid_1's binary_logloss: 0.241881
# [400]	training's auc: 0.81859	training's binary_logloss: 0.226535	valid_1's auc: 0.774422	valid_1's binary_logloss: 0.241028
# [500]	training's auc: 0.828189	training's binary_logloss: 0.22293	valid_1's auc: 0.775551	valid_1's binary_logloss: 0.240621
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.828189	training's binary_logloss: 0.22293	valid_1's auc: 0.775551	valid_1's binary_logloss: 0.240621
# |  15       |  0.7756   |  0.975    |  453.2    |  8.849    |  143.7    |  31.31    |  50.59    |  6.023    |  4.174    |  0.7796   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776344	training's binary_logloss: 0.243541	valid_1's auc: 0.756559	valid_1's binary_logloss: 0.248082
# [200]	training's auc: 0.797688	training's binary_logloss: 0.23466	valid_1's auc: 0.768001	valid_1's binary_logloss: 0.243425
# [300]	training's auc: 0.81288	training's binary_logloss: 0.228912	valid_1's auc: 0.772409	valid_1's binary_logloss: 0.241848
# [400]	training's auc: 0.82567	training's binary_logloss: 0.224074	valid_1's auc: 0.775414	valid_1's binary_logloss: 0.2408
# [500]	training's auc: 0.836736	training's binary_logloss: 0.219893	valid_1's auc: 0.776611	valid_1's binary_logloss: 0.240345
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.836736	training's binary_logloss: 0.219893	valid_1's auc: 0.776611	valid_1's binary_logloss: 0.240345
# |  16       |  0.7766   |  0.9248   |  443.7    |  13.32    |  138.7    |  12.81    |  59.84    |  9.45     |  1.863    |  0.7829   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775467	training's binary_logloss: 0.244255	valid_1's auc: 0.758191	valid_1's binary_logloss: 0.248042
# [200]	training's auc: 0.794822	training's binary_logloss: 0.235773	valid_1's auc: 0.768468	valid_1's binary_logloss: 0.243305
# [300]	training's auc: 0.809045	training's binary_logloss: 0.230335	valid_1's auc: 0.772968	valid_1's binary_logloss: 0.241642
# [400]	training's auc: 0.821003	training's binary_logloss: 0.225833	valid_1's auc: 0.775744	valid_1's binary_logloss: 0.240689
# [500]	training's auc: 0.831412	training's binary_logloss: 0.222004	valid_1's auc: 0.777146	valid_1's binary_logloss: 0.240206
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.831412	training's binary_logloss: 0.222004	valid_1's auc: 0.777146	valid_1's binary_logloss: 0.240206
# |  17       |  0.7771   |  0.681    |  437.7    |  12.79    |  143.3    |  13.72    |  50.63    |  6.026    |  2.739    |  0.7539   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774875	training's binary_logloss: 0.244374	valid_1's auc: 0.757753	valid_1's binary_logloss: 0.2481
# [200]	training's auc: 0.794341	training's binary_logloss: 0.235975	valid_1's auc: 0.768154	valid_1's binary_logloss: 0.243393
# [300]	training's auc: 0.808382	training's binary_logloss: 0.230616	valid_1's auc: 0.772498	valid_1's binary_logloss: 0.241766
# [400]	training's auc: 0.820435	training's binary_logloss: 0.226113	valid_1's auc: 0.775279	valid_1's binary_logloss: 0.240794
# [500]	training's auc: 0.830655	training's binary_logloss: 0.222318	valid_1's auc: 0.776349	valid_1's binary_logloss: 0.240377
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.830655	training's binary_logloss: 0.222318	valid_1's auc: 0.776349	valid_1's binary_logloss: 0.240377
# |  18       |  0.7763   |  0.7559   |  447.5    |  15.66    |  148.3    |  2.733    |  51.1     |  6.41     |  5.607    |  0.5214   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774714	training's binary_logloss: 0.243931	valid_1's auc: 0.756739	valid_1's binary_logloss: 0.247941
# [200]	training's auc: 0.796809	training's binary_logloss: 0.235034	valid_1's auc: 0.768404	valid_1's binary_logloss: 0.24324
# [300]	training's auc: 0.812014	training's binary_logloss: 0.229226	valid_1's auc: 0.773034	valid_1's binary_logloss: 0.241606
# [400]	training's auc: 0.824482	training's binary_logloss: 0.224554	valid_1's auc: 0.775608	valid_1's binary_logloss: 0.240733
# [500]	training's auc: 0.834764	training's binary_logloss: 0.220651	valid_1's auc: 0.776539	valid_1's binary_logloss: 0.240427
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.834764	training's binary_logloss: 0.220651	valid_1's auc: 0.776539	valid_1's binary_logloss: 0.240427
# |  19       |  0.7765   |  0.9743   |  440.1    |  11.8     |  158.4    |  25.92    |  50.89    |  0.3118   |  8.606    |  0.5562   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.773078	training's binary_logloss: 0.244905	valid_1's auc: 0.756542	valid_1's binary_logloss: 0.248438
# [200]	training's auc: 0.791881	training's binary_logloss: 0.236817	valid_1's auc: 0.767328	valid_1's binary_logloss: 0.243715
# [300]	training's auc: 0.805055	training's binary_logloss: 0.231784	valid_1's auc: 0.771844	valid_1's binary_logloss: 0.242059
# [400]	training's auc: 0.81612	training's binary_logloss: 0.22762	valid_1's auc: 0.774702	valid_1's binary_logloss: 0.241059
# [500]	training's auc: 0.825833	training's binary_logloss: 0.224037	valid_1's auc: 0.776211	valid_1's binary_logloss: 0.240531
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.825833	training's binary_logloss: 0.224037	valid_1's auc: 0.776211	valid_1's binary_logloss: 0.240531
# |  20       |  0.7762   |  0.8361   |  457.3    |  14.81    |  157.4    |  21.86    |  51.75    |  11.18    |  7.065    |  0.5612   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774385	training's binary_logloss: 0.243848	valid_1's auc: 0.757238	valid_1's binary_logloss: 0.247804
# [200]	training's auc: 0.79622	training's binary_logloss: 0.235117	valid_1's auc: 0.768433	valid_1's binary_logloss: 0.243229
# [300]	training's auc: 0.81101	training's binary_logloss: 0.229477	valid_1's auc: 0.772561	valid_1's binary_logloss: 0.241705
# [400]	training's auc: 0.823768	training's binary_logloss: 0.224835	valid_1's auc: 0.774856	valid_1's binary_logloss: 0.240922
# [500]	training's auc: 0.834469	training's binary_logloss: 0.220878	valid_1's auc: 0.776189	valid_1's binary_logloss: 0.24049
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.834469	training's binary_logloss: 0.220878	valid_1's auc: 0.776189	valid_1's binary_logloss: 0.24049
# |  21       |  0.7762   |  0.9222   |  442.6    |  8.859    |  150.2    |  14.13    |  48.35    |  1.521    |  1.188    |  0.9082   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.772609	training's binary_logloss: 0.245014	valid_1's auc: 0.756528	valid_1's binary_logloss: 0.24842
# [200]	training's auc: 0.791581	training's binary_logloss: 0.236884	valid_1's auc: 0.767485	valid_1's binary_logloss: 0.243642
# [300]	training's auc: 0.804929	training's binary_logloss: 0.231798	valid_1's auc: 0.772391	valid_1's binary_logloss: 0.241858
# [400]	training's auc: 0.816001	training's binary_logloss: 0.227698	valid_1's auc: 0.774905	valid_1's binary_logloss: 0.240951
# [500]	training's auc: 0.82554	training's binary_logloss: 0.224159	valid_1's auc: 0.776335	valid_1's binary_logloss: 0.240431
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.82554	training's binary_logloss: 0.224159	valid_1's auc: 0.776335	valid_1's binary_logloss: 0.240431
# |  22       |  0.7763   |  0.8254   |  450.7    |  11.76    |  143.8    |  18.95    |  48.94    |  8.294    |  8.719    |  0.8414   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779274	training's binary_logloss: 0.243909	valid_1's auc: 0.760462	valid_1's binary_logloss: 0.247923
# [200]	training's auc: 0.79773	training's binary_logloss: 0.2351	valid_1's auc: 0.769254	valid_1's binary_logloss: 0.243133
# [300]	training's auc: 0.812253	training's binary_logloss: 0.229432	valid_1's auc: 0.773331	valid_1's binary_logloss: 0.241491
# [400]	training's auc: 0.824809	training's binary_logloss: 0.224694	valid_1's auc: 0.775668	valid_1's binary_logloss: 0.240614
# [500]	training's auc: 0.83592	training's binary_logloss: 0.220487	valid_1's auc: 0.777166	valid_1's binary_logloss: 0.240061
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83592	training's binary_logloss: 0.220487	valid_1's auc: 0.777166	valid_1's binary_logloss: 0.240061
# |  23       |  0.7772   |  0.5037   |  428.3    |  13.59    |  143.0    |  22.67    |  58.95    |  6.368    |  3.751    |  0.8218   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.772732	training's binary_logloss: 0.245597	valid_1's auc: 0.7578	valid_1's binary_logloss: 0.248598
# [200]	training's auc: 0.790116	training's binary_logloss: 0.237576	valid_1's auc: 0.767745	valid_1's binary_logloss: 0.243667
# [300]	training's auc: 0.802684	training's binary_logloss: 0.232723	valid_1's auc: 0.772452	valid_1's binary_logloss: 0.241873
# [400]	training's auc: 0.81307	training's binary_logloss: 0.228884	valid_1's auc: 0.774991	valid_1's binary_logloss: 0.240954
# [500]	training's auc: 0.822279	training's binary_logloss: 0.225476	valid_1's auc: 0.776653	valid_1's binary_logloss: 0.240366
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.822279	training's binary_logloss: 0.225476	valid_1's auc: 0.776653	valid_1's binary_logloss: 0.240366
# |  24       |  0.7767   |  0.5679   |  432.7    |  13.13    |  136.6    |  20.23    |  47.15    |  8.216    |  8.913    |  0.7182   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775503	training's binary_logloss: 0.244145	valid_1's auc: 0.756835	valid_1's binary_logloss: 0.248242
# [200]	training's auc: 0.795792	training's binary_logloss: 0.235502	valid_1's auc: 0.767915	valid_1's binary_logloss: 0.243503
# [300]	training's auc: 0.81021	training's binary_logloss: 0.229964	valid_1's auc: 0.772462	valid_1's binary_logloss: 0.241838
# [400]	training's auc: 0.822501	training's binary_logloss: 0.225368	valid_1's auc: 0.775158	valid_1's binary_logloss: 0.240894
# [500]	training's auc: 0.833132	training's binary_logloss: 0.221357	valid_1's auc: 0.776539	valid_1's binary_logloss: 0.24038
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.833132	training's binary_logloss: 0.221357	valid_1's auc: 0.776539	valid_1's binary_logloss: 0.24038
# |  25       |  0.7765   |  0.8504   |  433.1    |  15.39    |  154.8    |  16.52    |  57.73    |  8.9      |  9.122    |  0.8634   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.772721	training's binary_logloss: 0.245719	valid_1's auc: 0.757643	valid_1's binary_logloss: 0.24874
# [200]	training's auc: 0.789542	training's binary_logloss: 0.237815	valid_1's auc: 0.767409	valid_1's binary_logloss: 0.24384
# [300]	training's auc: 0.801921	training's binary_logloss: 0.233035	valid_1's auc: 0.772168	valid_1's binary_logloss: 0.242
# [400]	training's auc: 0.811812	training's binary_logloss: 0.229324	valid_1's auc: 0.774531	valid_1's binary_logloss: 0.241127
# [500]	training's auc: 0.820948	training's binary_logloss: 0.225949	valid_1's auc: 0.776255	valid_1's binary_logloss: 0.240482
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.820948	training's binary_logloss: 0.225949	valid_1's auc: 0.776255	valid_1's binary_logloss: 0.240482
# |  26       |  0.7763   |  0.5765   |  419.0    |  15.54    |  146.4    |  22.4     |  49.61    |  12.51    |  9.178    |  0.6284   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777428	training's binary_logloss: 0.243924	valid_1's auc: 0.759453	valid_1's binary_logloss: 0.247907
# [200]	training's auc: 0.79686	training's binary_logloss: 0.235189	valid_1's auc: 0.769144	valid_1's binary_logloss: 0.243148
# [300]	training's auc: 0.811535	training's binary_logloss: 0.229554	valid_1's auc: 0.773394	valid_1's binary_logloss: 0.24153
# [400]	training's auc: 0.82413	training's binary_logloss: 0.224785	valid_1's auc: 0.77606	valid_1's binary_logloss: 0.240566
# [500]	training's auc: 0.835149	training's binary_logloss: 0.220715	valid_1's auc: 0.777338	valid_1's binary_logloss: 0.24015
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835149	training's binary_logloss: 0.220715	valid_1's auc: 0.777338	valid_1's binary_logloss: 0.24015
# |  27       |  0.7773   |  0.5964   |  425.2    |  15.73    |  138.6    |  17.45    |  53.0     |  5.158    |  1.202    |  0.5967   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777633	training's binary_logloss: 0.24351	valid_1's auc: 0.758547	valid_1's binary_logloss: 0.247753
# [200]	training's auc: 0.798278	training's binary_logloss: 0.234701	valid_1's auc: 0.768994	valid_1's binary_logloss: 0.243093
# [300]	training's auc: 0.812596	training's binary_logloss: 0.229107	valid_1's auc: 0.773413	valid_1's binary_logloss: 0.241435
# [400]	training's auc: 0.824484	training's binary_logloss: 0.224607	valid_1's auc: 0.775665	valid_1's binary_logloss: 0.240664
# [500]	training's auc: 0.835107	training's binary_logloss: 0.220619	valid_1's auc: 0.776842	valid_1's binary_logloss: 0.240229
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835107	training's binary_logloss: 0.220619	valid_1's auc: 0.776842	valid_1's binary_logloss: 0.240229
# |  28       |  0.7768   |  0.6868   |  430.1    |  8.64     |  132.1    |  21.7     |  57.11    |  5.181    |  2.104    |  0.998    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779159	training's binary_logloss: 0.242658	valid_1's auc: 0.758832	valid_1's binary_logloss: 0.247488
# [200]	training's auc: 0.801937	training's binary_logloss: 0.233252	valid_1's auc: 0.769277	valid_1's binary_logloss: 0.242922
# [300]	training's auc: 0.818834	training's binary_logloss: 0.22684	valid_1's auc: 0.773454	valid_1's binary_logloss: 0.241401
# [400]	training's auc: 0.833113	training's binary_logloss: 0.221465	valid_1's auc: 0.776028	valid_1's binary_logloss: 0.24051
# [500]	training's auc: 0.845321	training's binary_logloss: 0.216881	valid_1's auc: 0.777003	valid_1's binary_logloss: 0.240154
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.845321	training's binary_logloss: 0.216881	valid_1's auc: 0.777003	valid_1's binary_logloss: 0.240154
# |  29       |  0.777    |  0.7574   |  411.1    |  15.6     |  125.9    |  15.14    |  60.4     |  4.044    |  1.064    |  0.749    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.780978	training's binary_logloss: 0.242569	valid_1's auc: 0.759597	valid_1's binary_logloss: 0.24748
# [200]	training's auc: 0.803255	training's binary_logloss: 0.232977	valid_1's auc: 0.769556	valid_1's binary_logloss: 0.242912
# [300]	training's auc: 0.820044	training's binary_logloss: 0.226484	valid_1's auc: 0.773936	valid_1's binary_logloss: 0.241293
# [400]	training's auc: 0.834179	training's binary_logloss: 0.22112	valid_1's auc: 0.776345	valid_1's binary_logloss: 0.240481
# [500]	training's auc: 0.845936	training's binary_logloss: 0.216561	valid_1's auc: 0.777033	valid_1's binary_logloss: 0.240215
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.845936	training's binary_logloss: 0.216561	valid_1's auc: 0.777033	valid_1's binary_logloss: 0.240215
# |  30       |  0.777    |  0.6436   |  421.7    |  13.65    |  127.9    |  24.61    |  61.91    |  0.4899   |  6.11     |  0.5538   |
# =====================================================================================================================================

# %% [markdown]
# ##### Iteration 수행 결과 출력

# %%
# BayesianOptimization객체의 res는 iteration 수행 시마다 모든 함수 반환결과와 그때의 파라미터 결과값을 가지고 있음. 
lgbBO.res
# Out:
# [{'target': 0.7750711591318917,
#   'params': {'colsample_bytree': 0.7744067519636624,
#    'max_bin': 360.44278952248555,
#    'max_depth': 12.822107008573152,
#    'min_child_samples': 113.52780476941041,
#    'min_child_weight': 21.75908516760633,
#    'num_leaves': 49.835764522666246,
#    'reg_alpha': 21.884984691022,
#    'reg_lambda': 8.917838234820016,
#    'subsample': 0.9818313802505146}},
#  {'target': 0.7754903471319594,
#   'params': {'colsample_bytree': 0.6917207594128889,
#    'max_bin': 397.94526866050563,
#    'max_depth': 12.231159358023236,
#    'min_child_samples': 117.92846660784714,
#    'min_child_weight': 46.35423527634039,
#    'num_leaves': 26.841442327915477,
#    'reg_alpha': 4.36559369208002,
#    'reg_lambda': 0.20316375600581688,
#    'subsample': 0.916309922773969}},
#  {'target': 0.7766631007671749,
#   'params': {'colsample_bytree': 0.8890783754749252,
#    'max_bin': 436.30595264094137,
#    'max_depth': 15.828946737862111,
#    'min_child_samples': 161.8401272011775,
#    'min_child_weight': 23.61248875039366,
#    'num_leaves': 55.22116705145822,
#    'reg_alpha': 5.922538549187972,
#    'reg_lambda': 6.3995702922539115,
#    'subsample': 0.5716766437045232}},
#  {'target': 0.7743055911908209,
#   'params': {'colsample_bytree': 0.972334458524792,
#    'max_bin': 265.70567765753515,
#    'max_depth': 11.317295519924189,
#    'min_child_samples': 60.265566299879126,
#    'min_child_weight': 38.93745078227661,
#    'num_leaves': 42.24601328866194,
#    'reg_alpha': 28.426013103943742,
#    'reg_lambda': 0.18887921456311507,
#    'subsample': 0.8088177485379385}},
#  {'target': 0.7737539076452709,
#   'params': {'colsample_bytree': 0.8060478613612108,
#    'max_bin': 312.2976584686309,
#    'max_depth': 15.549984628116993,
#    'min_child_samples': 139.54585682966186,
#    'min_child_weight': 18.615887128115514,
#    'num_leaves': 41.481278151973655,
#    'reg_alpha': 34.88458348440397,
#    'reg_lambda': 0.6031944908210691,
#    'subsample': 0.8333833577228338}},
#  {'target': 0.7751370018506345,
#   'params': {'colsample_bytree': 0.8491600608524768,
#    'max_bin': 489.74739714335925,
#    'max_depth': 8.980826912350402,
#    'min_child_samples': 133.02480133869085,
#    'min_child_weight': 9.606886109874106,
#    'num_leaves': 57.99214561976929,
#    'reg_alpha': 23.74181736171718,
#    'reg_lambda': 6.017526517483127,
#    'subsample': 0.9803004928763657}},
#  {'target': 0.7769928750826987,
#   'params': {'colsample_bytree': 0.6269424481115744,
#    'max_bin': 437.7139376223468,
#    'max_depth': 11.254324094723868,
#    'min_child_samples': 156.49990300466584,
#    'min_child_weight': 22.141960867869216,
#    'num_leaves': 48.87410910290432,
#    'reg_alpha': 2.4315424555760057,
#    'reg_lambda': 7.9476159252537135,
#    'subsample': 0.8026954760296108}},
#  {'target': 0.7755281489948975,
#   'params': {'colsample_bytree': 0.6075914230856632,
#    'max_bin': 440.9257976456061,
#    'max_depth': 12.624214042424997,
#    'min_child_samples': 172.28148380113822,
#    'min_child_weight': 7.485357397759047,
#    'num_leaves': 25.5035079919381,
#    'reg_alpha': 3.0273084945887248,
#    'reg_lambda': 8.937722250801897,
#    'subsample': 0.6856977582007306}},
#  {'target': 0.7759108471892922,
#   'params': {'colsample_bytree': 0.9976988559046107,
#    'max_bin': 436.57429360685126,
#    'max_depth': 9.000357110023092,
#    'min_child_samples': 147.38802288954847,
#    'min_child_weight': 45.38701862513499,
#    'num_leaves': 52.60686439274362,
#    'reg_alpha': 3.911968876197347,
#    'reg_lambda': 1.3621745268025773,
#    'subsample': 0.5864174784235351}},
#  {'target': 0.7770353279186044,
#   'params': {'colsample_bytree': 0.6700563145970178,
#    'max_bin': 440.18864333796887,
#    'max_depth': 12.742156283520405,
#    'min_child_samples': 140.40605969425937,
#    'min_child_weight': 9.368094296702132,
#    'num_leaves': 57.783926145808714,
#    'reg_alpha': 3.511650373357953,
#    'reg_lambda': 3.1105255187613725,
#    'subsample': 0.948643468468342}},
#  {'target': 0.7765152401733609,
#   'params': {'colsample_bytree': 0.6897027749377616,
#    'max_bin': 437.09319304145265,
#    'max_depth': 10.657825973996161,
#    'min_child_samples': 139.7549130397934,
#    'min_child_weight': 7.790053083480294,
#    'num_leaves': 56.60825078504662,
#    'reg_alpha': 9.517086843319586,
#    'reg_lambda': 1.8850035455230474,
#    'subsample': 0.7772561067027193}},
#  {'target': 0.7770139267714758,
#   'params': {'colsample_bytree': 0.5482250170663707,
#    'max_bin': 456.2589029178213,
#    'max_depth': 10.320478574170547,
#    'min_child_samples': 150.15129921273,
#    'min_child_weight': 18.038076845288554,
#    'num_leaves': 53.900570325016176,
#    'reg_alpha': 1.2194956325974453,
#    'reg_lambda': 8.931013494987054,
#    'subsample': 0.6952969162419964}},
#  {'target': 0.7772316853893558,
#   'params': {'colsample_bytree': 0.6982375014708819,
#    'max_bin': 451.77355731928196,
#    'max_depth': 12.040874499971638,
#    'min_child_samples': 147.62304529430287,
#    'min_child_weight': 25.299302773090673,
#    'num_leaves': 52.542314968439555,
#    'reg_alpha': 5.749561058810155,
#    'reg_lambda': 3.5459227271720657,
#    'subsample': 0.8092304522276567}},
#  {'target': 0.7767504653550223,
#   'params': {'colsample_bytree': 0.6832926911884427,
#    'max_bin': 452.8127926612667,
#    'max_depth': 13.748648823492271,
#    'min_child_samples': 105.32019265730692,
#    'min_child_weight': 37.53924683031443,
#    'num_leaves': 47.91758473162237,
#    'reg_alpha': 1.0484859565890867,
#    'reg_lambda': 7.681525906606172,
#    'subsample': 0.597408012012018}},
#  {'target': 0.7755510003941842,
#   'params': {'colsample_bytree': 0.9749878985875149,
#    'max_bin': 453.18836024645185,
#    'max_depth': 8.84873595648995,
#    'min_child_samples': 143.65422812025258,
#    'min_child_weight': 31.306047702833748,
#    'num_leaves': 50.58850901641458,
#    'reg_alpha': 6.0232620473607925,
#    'reg_lambda': 4.173557134768171,
#    'subsample': 0.7795780144320175}},
#  {'target': 0.7766107376101133,
#   'params': {'colsample_bytree': 0.9247947685820762,
#    'max_bin': 443.7004390173623,
#    'max_depth': 13.316566378038132,
#    'min_child_samples': 138.68359717045072,
#    'min_child_weight': 12.813267108190148,
#    'num_leaves': 59.84492938088712,
#    'reg_alpha': 9.44998202537815,
#    'reg_lambda': 1.8627556270989953,
#    'subsample': 0.7829207439817324}},
#  {'target': 0.777146328598582,
#   'params': {'colsample_bytree': 0.6809769333852504,
#    'max_bin': 437.71707386567437,
#    'max_depth': 12.790997984399679,
#    'min_child_samples': 143.28833515916693,
#    'min_child_weight': 13.715267184524041,
#    'num_leaves': 50.625185919472386,
#    'reg_alpha': 6.025839222172876,
#    'reg_lambda': 2.7393283658063603,
#    'subsample': 0.7538931075991632}},
#  {'target': 0.7763494063011563,
#   'params': {'colsample_bytree': 0.7558854639355026,
#    'max_bin': 447.4742981411086,
#    'max_depth': 15.664542121869303,
#    'min_child_samples': 148.31653920735786,
#    'min_child_weight': 2.73308509037741,
#    'num_leaves': 51.10227524472864,
#    'reg_alpha': 6.410147098289009,
#    'reg_lambda': 5.607259524099217,
#    'subsample': 0.5214002742061654}},
#  {'target': 0.7765387857240095,
#   'params': {'colsample_bytree': 0.9742992835653523,
#    'max_bin': 440.1034550248382,
#    'max_depth': 11.795363807189577,
#    'min_child_samples': 158.35790568308187,
#    'min_child_weight': 25.92146432007338,
#    'num_leaves': 50.89450318915966,
#    'reg_alpha': 0.31184343639773765,
#    'reg_lambda': 8.606337163025708,
#    'subsample': 0.5561675965344454}},
#  {'target': 0.7762112685917463,
#   'params': {'colsample_bytree': 0.8361049922084773,
#    'max_bin': 457.25047204646404,
#    'max_depth': 14.812997885493928,
#    'min_child_samples': 157.40215598782697,
#    'min_child_weight': 21.858460519107588,
#    'num_leaves': 51.74509949262811,
#    'reg_alpha': 11.184485850434655,
#    'reg_lambda': 7.064555456123726,
#    'subsample': 0.5612401022732377}},
#  {'target': 0.7761887904775167,
#   'params': {'colsample_bytree': 0.9222190911988164,
#    'max_bin': 442.5694432412386,
#    'max_depth': 8.859415285288343,
#    'min_child_samples': 150.18956194738763,
#    'min_child_weight': 14.128916535263745,
#    'num_leaves': 48.35219447870037,
#    'reg_alpha': 1.5209982272347846,
#    'reg_lambda': 1.1878876230866524,
#    'subsample': 0.9081628279517028}},
#  {'target': 0.7763350499167023,
#   'params': {'colsample_bytree': 0.8253680490269797,
#    'max_bin': 450.70307333775355,
#    'max_depth': 11.762943341543,
#    'min_child_samples': 143.84440992531123,
#    'min_child_weight': 18.9522381224018,
#    'num_leaves': 48.93815524839941,
#    'reg_alpha': 8.293859241458744,
#    'reg_lambda': 8.718717164656788,
#    'subsample': 0.8413938003756276}},
#  {'target': 0.7771657568944721,
#   'params': {'colsample_bytree': 0.5037340419126779,
#    'max_bin': 428.3057212840207,
#    'max_depth': 13.586724695329199,
#    'min_child_samples': 143.0120838185431,
#    'min_child_weight': 22.671818221801573,
#    'num_leaves': 58.95340776367052,
#    'reg_alpha': 6.367837040114049,
#    'reg_lambda': 3.750655650350553,
#    'subsample': 0.8218461697864226}},
#  {'target': 0.7766526138397392,
#   'params': {'colsample_bytree': 0.5678809596516503,
#    'max_bin': 432.6595346485251,
#    'max_depth': 13.131552522741137,
#    'min_child_samples': 136.6495623998792,
#    'min_child_weight': 20.225012568639272,
#    'num_leaves': 47.14770387182597,
#    'reg_alpha': 8.215654414660014,
#    'reg_lambda': 8.912621930928866,
#    'subsample': 0.7181875479254518}},
#  {'target': 0.7765387285399156,
#   'params': {'colsample_bytree': 0.8503986056496755,
#    'max_bin': 433.09500496883135,
#    'max_depth': 15.386301203705505,
#    'min_child_samples': 154.75341650407097,
#    'min_child_weight': 16.517850206857524,
#    'num_leaves': 57.73495106870535,
#    'reg_alpha': 8.899791866040571,
#    'reg_lambda': 9.121542000354047,
#    'subsample': 0.863411921956049}},
#  {'target': 0.776254709441718,
#   'params': {'colsample_bytree': 0.5764926592612852,
#    'max_bin': 419.0441509702066,
#    'max_depth': 15.539821652777233,
#    'min_child_samples': 146.41422325573106,
#    'min_child_weight': 22.399357003921423,
#    'num_leaves': 49.609351902740315,
#    'reg_alpha': 12.507241290675584,
#    'reg_lambda': 9.177828288276249,
#    'subsample': 0.6284270221848508}},
#  {'target': 0.777338006504319,
#   'params': {'colsample_bytree': 0.5963848546286805,
#    'max_bin': 425.2039213582727,
#    'max_depth': 15.732873087684553,
#    'min_child_samples': 138.58474143742762,
#    'min_child_weight': 17.44603386559871,
#    'num_leaves': 52.998983105551915,
#    'reg_alpha': 5.158499666358166,
#    'reg_lambda': 1.2023610908493259,
#    'subsample': 0.5966699785796546}},
#  {'target': 0.7768419154286869,
#   'params': {'colsample_bytree': 0.6868009551596232,
#    'max_bin': 430.1206629194153,
#    'max_depth': 8.6395982340016,
#    'min_child_samples': 132.139923385572,
#    'min_child_weight': 21.697151963990745,
#    'num_leaves': 57.105831906574494,
#    'reg_alpha': 5.180815579842702,
#    'reg_lambda': 2.1040194739570914,
#    'subsample': 0.9979512076729464}},
#  {'target': 0.7770033524794522,
#   'params': {'colsample_bytree': 0.7574025491856033,
#    'max_bin': 411.14581622466187,
#    'max_depth': 15.595204557074968,
#    'min_child_samples': 125.87065467543844,
#    'min_child_weight': 15.135753134202838,
#    'num_leaves': 60.40493288640114,
#    'reg_alpha': 4.044212052235154,
#    'reg_lambda': 1.0640265596910639,
#    'subsample': 0.7489790591924238}},
#  {'target': 0.7770334043092246,
#   'params': {'colsample_bytree': 0.6435983080924714,
#    'max_bin': 421.70641586642563,
#    'max_depth': 13.648233542599783,
#    'min_child_samples': 127.94784702607348,
#    'min_child_weight': 24.613749623045617,
#    'num_leaves': 61.905356648278875,
#    'reg_alpha': 0.489949227649363,
#    'reg_lambda': 6.109783578567888,
#    'subsample': 0.5537625330239078}}]

# %% [markdown]
# ##### Iteration 결과 Dictionary에서 최대 target값을 가지는 index 추출하고 그때의 parameter 값을 추출.

# %%
# dictionary에 있는 target값을 모두 추출
target_list = []
for result in lgbBO.res:
    target = result['target']
    target_list.append(target)
print(target_list)
# 가장 큰 target 값을 가지는 순번(index)를 추출
print('maximum target index:', np.argmax(np.array(target_list)))
# Out:
# [0.7750711591318917, 0.7754903471319594, 0.7766631007671749, 0.7743055911908209, 0.7737539076452709, 0.7751370018506345, 0.7769928750826987, 0.7755281489948975, 0.7759108471892922, 0.7770353279186044, 0.7765152401733609, 0.7770139267714758, 0.7772316853893558, 0.7767504653550223, 0.7755510003941842, 0.7766107376101133, 0.777146328598582, 0.7763494063011563, 0.7765387857240095, 0.7762112685917463, 0.7761887904775167, 0.7763350499167023, 0.7771657568944721, 0.7766526138397392, 0.7765387285399156, 0.776254709441718, 0.777338006504319, 0.7768419154286869, 0.7770033524794522, 0.7770334043092246]
# maximum target index: 26

# %%
# 가장 큰 target값을 가지는 index값을 기준으로 res에서 해당 parameter 추출. 
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.777338006504319, 'params': {'colsample_bytree': 0.5963848546286805, 'max_bin': 425.2039213582727, 'max_depth': 15.732873087684553, 'min_child_samples': 138.58474143742762, 'min_child_weight': 17.44603386559871, 'num_leaves': 52.998983105551915, 'reg_alpha': 5.158499666358166, 'reg_lambda': 1.2023610908493259, 'subsample': 0.5966699785796546}}

# %% [markdown]
# ##### 최적화된 하이퍼 파라미터를 기반으로 재 테스트

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 15,
                num_leaves=52,
                colsample_bytree=0.596,
                subsample=0.682,
                max_bin=425,
                reg_alpha=5.158,
                reg_lambda=1.202,
                min_child_weight=17,
                min_child_samples=138,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)
# Out:
# prev_agg shape: (338857, 41)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 176)
# train shape: (215257, 174) valid shape: (92254, 174)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777077	training's binary_logloss: 0.243966	valid_1's auc: 0.759095	valid_1's binary_logloss: 0.24798
# [200]	training's auc: 0.796345	training's binary_logloss: 0.235286	valid_1's auc: 0.769032	valid_1's binary_logloss: 0.243178
# [300]	training's auc: 0.811169	training's binary_logloss: 0.229611	valid_1's auc: 0.773504	valid_1's binary_logloss: 0.241493
# [400]	training's auc: 0.823851	training's binary_logloss: 0.224899	valid_1's auc: 0.776009	valid_1's binary_logloss: 0.240593
# [500]	training's auc: 0.83474	training's binary_logloss: 0.220865	valid_1's auc: 0.777169	valid_1's binary_logloss: 0.240173
# [600]	training's auc: 0.844313	training's binary_logloss: 0.217223	valid_1's auc: 0.777853	valid_1's binary_logloss: 0.239925
# [700]	training's auc: 0.85315	training's binary_logloss: 0.213835	valid_1's auc: 0.778322	valid_1's binary_logloss: 0.239776
# [800]	training's auc: 0.861322	training's binary_logloss: 0.210564	valid_1's auc: 0.778729	valid_1's binary_logloss: 0.239647
# [900]	training's auc: 0.86895	training's binary_logloss: 0.207491	valid_1's auc: 0.778945	valid_1's binary_logloss: 0.239568
# [1000]	training's auc: 0.87598	training's binary_logloss: 0.204563	valid_1's auc: 0.778926	valid_1's binary_logloss: 0.239565
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.87598	training's binary_logloss: 0.204563	valid_1's auc: 0.778926	valid_1's binary_logloss: 0.239565

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1 ]
apps_all_test['TARGET'] = preds
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv('prev_baseline_tuning_01.csv', index=False)

# %% [markdown]
# ##### cross validation 으로 hyper parameter 재 tuning

# %%
bayesian_params = {
    'max_depth': (6, 16), 
    'num_leaves': (24, 64), 
    'min_data_in_leaf': (10, 200), # min_child_samples
    'min_child_weight':(1, 50),
    'bagging_fraction':(0.5, 1.0), # subsample
    'feature_fraction': (0.5, 1.0), # colsample_bytree
    'max_bin':(10, 500),
    'lambda_l2':(0.001, 10), # reg_lambda
    'lambda_l1': (0.01, 50) # reg_alpha
}

# %%
import lightgbm as lgb

train_data = lgb.Dataset(data=ftr_app, label=target_app, free_raw_data=False)
def lgb_roc_eval_cv(max_depth, num_leaves, min_data_in_leaf, min_child_weight, bagging_fraction, 
                 feature_fraction,  max_bin, lambda_l2, lambda_l1):   
    params = {
        "num_iterations":500, "learning_rate":0.02,
        'early_stopping_rounds':100, 'metric':'auc',
        'max_depth': int(round(max_depth)), #  호출 시 실수형 값이 들어오므로 실수형 하이퍼 파라미터는 정수형으로 변경 
        'num_leaves': int(round(num_leaves)), 
        'min_data_in_leaf': int(round(min_data_in_leaf)),
        'min_child_weight': int(round(min_child_weight)),
        'bagging_fraction': max(min(bagging_fraction, 1), 0), 
        'feature_fraction': max(min(feature_fraction, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),
        'lambda_l2': max(lambda_l2,0),
        'lambda_l1': max(lambda_l1, 0)
    }
    # 파이썬 lightgbm의 cv 메소드를 사용. 
    
    cv_result = lgb.cv(params, train_data, nfold=3, seed=0,  verbose_eval =100,  early_stopping_rounds=50, metrics=['auc'])
    return max(cv_result['auc-mean'])

# %%
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 10,
                num_leaves=60,
                colsample_bytree=0.511,
                subsample=0.785,
                max_bin=208,
                reg_alpha=7.009,
                reg_lambda=6.579,
                min_child_weight=40,
                min_child_samples=91,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1 ]
apps_all_test['TARGET'] = preds
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv('prev_baseline_tuning_02.csv', index=False)
