# %% [markdown]
# ## wordcloud 설치

# %%
# !conda install -y -c conda-forge wordcloud
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\leeji\anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wordcloud-1.8.1            |   py38h294d835_1         196 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         196 KB
#
# The following NEW packages will be INSTALLED:
#
#   wordcloud          conda-forge/win-64::wordcloud-1.8.1-py38h294d835_1
#
#
#
# Downloading and Extracting Packages
#
# wordcloud-1.8.1      | 196 KB    |            |   0%
# wordcloud-1.8.1      | 196 KB    | ######5    |  65%
# wordcloud-1.8.1      | 196 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd

# %%
word_count = pd.read_csv('word_count.csv', index_col=0)

# %%
word_count.sort_values('빈도', ascending=False).head()
# Out:
#         단어   빈도
# 284  movie  182
# 153   film  163
# 33     bad   71
# 225   just   63
# 178   good   58

# %% [markdown]
# ## 단어 구름

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color='white', max_words=100, width=400, height=300)

# %%
# 사전 형태
count_dic = word_count.set_index('단어')['빈도'].to_dict()

# %%
count_dic = dict(zip(word_count['단어'], word_count['빈도']))

# %%
cloud = wc.fit_words(count_dic)

# %%
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x174F988D160>

# %%
cloud.to_file('cloud.png')

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\leeji\\ML_\\강의\\텍스트데이터분석'
