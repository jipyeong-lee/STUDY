# %%
import pandas as pd
word_count = pd.read_excel('nsmc-count.xlsx')

# %%
word_count.sort_values('빈도', ascending=False).head()
# Out:
#     Unnamed: 0  단어  빈도
# 47          47  영화  19
# 46          46  연기   6
# 49          49  완전   6
# 9            9  내용   5
# 92          92  진짜   5

# %%
count_dic = word_count.set_index('단어')['빈도'].to_dict()

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path='C:/Users/leeji/Desktop/NanumFontSetup_TTF_GOTHIC/NanumGothic.ttf', background_color='white', width=400, height=300)

# %%
cloud = wc.generate_from_frequencies(count_dic)

# %%
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x2608ABEC130>
